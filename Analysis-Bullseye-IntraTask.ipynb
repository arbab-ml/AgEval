# %%
# dataset_mapping = {
#     'Durum Wheat': ('Identification (I)', 'F1 Score', 'Crop Type'),
#     'Soybean Seeds': ('Identification (I)', 'F1 Score', 'Crop Type'),
#     'Mango Leaf Disease': ('Identification (I)', 'F1 Score', 'Disease Type'),
#     'Bean Leaf Lesions': ('Identification (I)', 'F1 Score', 'Disease Type'),
#     'DeepWeeds': ('Identification (I)', 'F1 Score', 'Pest Type'),
#     'IP02': ('Identification (I)', 'F1 Score', 'Pest Type'),
#     'SBRD': ('Identification (I)', 'F1 Score', 'Disease Stage'),
#     'Yellow Rust 19': ('Classification (C)', 'NMAE', 'Disease Stage'),
#     'FUSARIUM 22': ('Classification (C)', 'NMAE', 'Leaf Health'),
#     'InsectCount': ('Quantification (Q)', 'NMAE', 'Pest Count'),
#     'PlantDoc': ('Quantification (Q)', 'NMAE', 'Disease Quantification'),
# }




# so the fixed mapping is

    # 'SBRD': ('Identification (I)', 'F1', 'Disease Severity'),
# removed

# %%
dataset_mapping = {
    'Durum Wheat': ('Identification (I)', 'F1', 'Seed Morphology'),
    'Soybean Seeds': ('Identification (I)', 'F1', 'Seed Morphology'),
    'Mango Leaf Disease': ('Identification (I)', 'F1', 'Foliar Stress'),
    'Bean Leaf Lesions': ('Identification (I)', 'F1', 'Foliar Stress'),
    'Soybean Diseases': ('Identification (I)', 'F1', 'Foliar Stress'),
    'Dangerous Insects': ('Identification (I)', 'F1', 'Invasive Species'),
    'DeepWeeds': ('Identification (I)', 'F1', 'Invasive Species'),
    'Yellow Rust 19': ('Classification (C)', 'NMAE', 'Disease Severity'),
    'IDC': ('Classification (C)', 'NMAE', 'Stress Tolerance'),
    'FUSARIUM 22': ('Classification (C)', 'NMAE', 'Stress Tolerance'),
    'InsectCount': ('Quantification (Q)', 'NMAE', 'Pest'),
    'PlantDoc': ('Quantification (Q)', 'NMAE', 'Disease'),
}

# %%
# new mapping


import os
import pandas as pd
import numpy as np
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix, mean_absolute_error

# Define the datasets and their categories, metrics, and subcategories


result_table_dict={}
for this_shot in [0,1,2,4,8]:
    def calculate_metric(df, category, dataset_name):
        print(f"Processing {dataset_name}...")
        true_labels = df['1'].fillna('Unknown')
        pred_labels = df[f'# of Shots {this_shot}'].fillna('NA_placeholder')
        
        if category == 'Identification (I)':
            # Use F1 score for category I
            precision, recall, f1, _ = precision_recall_fscore_support(true_labels, pred_labels, average='weighted', zero_division=0)
            return f1 * 100
        elif category == 'Classification (C)':
            # Use normalized MAE for ordinal classification
            if dataset_name == 'FUSARIUM 22':
                ordinal_map = {
                    'Highly Resistant': 1,
                    'Resistant': 2,
                    'Moderately Resistant': 3,
                    'Susceptible': 4,
                    'Highly Susceptible': 5,
                }
            elif dataset_name == 'Yellow Rust 19':
                ordinal_map = {
                    'Resistant (R)': 1,
                    'Moderately Resistant (MR)': 2,
                    'MRMS': 3,
                    'Moderately Susceptible (MS)': 4,
                    'Susceptible (S)': 5,
                    'No disease (0)': 0,
                }
            elif dataset_name == 'IDC':
                ordinal_map = {i: i for i in range(1, 6)}

            else:
                raise ValueError(f"Unknown dataset for category C: {dataset_name}")
            
            # Add unseen labels to the ordinal map with the worst score
            max_value = max(ordinal_map.values())
            all_labels = set(true_labels).union(set(pred_labels))
            for label in all_labels:
                if label not in ordinal_map:
                    ordinal_map[label] = max_value + 1
            
            true_ordinal = true_labels.map(ordinal_map)
            pred_ordinal = pred_labels.map(ordinal_map)
            
            # Calculate normalized MAE
            mae = np.mean(np.abs(true_ordinal - pred_ordinal))
            max_possible_error = max(ordinal_map.values()) - min(ordinal_map.values())
            if max_possible_error == 0:
                print(f"Warning: All values are the same for {dataset_name}")
                return 0.0  # Perfect prediction if all values are the same
            normalized_mae = (mae / max_possible_error) * 100
            
            return normalized_mae
        elif category == 'Quantification (Q)':
            try:
                true_values = pd.to_numeric(true_labels, errors='coerce')
                pred_values = pd.to_numeric(pred_labels, errors='coerce')
                
                # Remove rows where either true_values or pred_values is NaN
                mask = ~(true_values.isna() | pred_values.isna())
                true_values = true_values[mask]
                pred_values = pred_values[mask]
                
                if len(true_values) == 0:
                    print(f"Warning: No valid numeric data for {dataset_name}")
                    return np.nan
                
                # Calculate MAPE (avoiding division by zero)
                non_zero_mask = true_values != 0
                if non_zero_mask.sum() == 0:
                    print(f"Warning: All true values are zero for {dataset_name}")
                    mape = np.nan
                else:
                    mape = np.mean(np.abs((true_values[non_zero_mask] - pred_values[non_zero_mask]) / true_values[non_zero_mask])) * 100
                
                # Calculate normalized MAE
                mae = np.mean(np.abs(true_values - pred_values))
                max_possible_error = true_values.max() - true_values.min()
                if max_possible_error == 0:
                    print(f"Warning: All values are the same for {dataset_name}")
                    normalized_mae = 0.0  # Perfect prediction if all values are the same
                else:
                    normalized_mae = (mae / max_possible_error) * 100
                
                return normalized_mae  # or return mape, depending on preference
            except Exception as e:
                print(f"Error in quantification for {dataset_name}: {str(e)}")
                return np.nan
    # Get the list of model folders
    model_folders = [f for f in os.listdir('results') if os.path.isdir(os.path.join('results', f))]

    # Initialize results dictionary
    results = {model: {} for model in model_folders}

    # Process each dataset for each model
    for model in model_folders:
        for dataset, (category, metric, subcategory) in dataset_mapping.items():
            try:
                df = pd.read_csv(f'results/{model}/{dataset}.csv', engine='python')
                result = calculate_metric(df, category, dataset)
                results[model][dataset] = result
            except FileNotFoundError:
                print(f"File not found: results/{model}/{dataset}.csv")
                results[model][dataset] = np.nan
            except Exception as e:
                print(f"Error processing {model}/{dataset}: {str(e)}")
                results[model][dataset] = np.nan

    # Create the result table
    result_table = pd.DataFrame(results).T  # Transpose to match the desired format

    # Rename the index and columns
    result_table.index.name = 'Model'
    result_table.columns.name = 'Dataset'

    # Round the results to 2 decimal places
    result_table = result_table.round(2)

    # Create multi-level columns
    columns = pd.MultiIndex.from_tuples([
        (category, metric, subcategory, dataset)
        for dataset, (category, metric, subcategory) in dataset_mapping.items()
    ])

    # Reorder and rename columns
    result_table = result_table.reindex(columns=columns.get_level_values(3))
    result_table.columns = columns

    print(result_table)
    result_table_dict[this_shot]=result_table.copy(deep= True)
    # Optionally, save the result table to a CSV file
    result_table.to_csv(f'analysis/plain-results/result_table_shot_{this_shot}.csv')
# Out:
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
#                   Identification (I)                                   \
#                                   F1
#                      Seed Morphology                    Foliar Stress
#                          Durum Wheat Soybean Seeds Mango Leaf Disease
# Model
# Gemini-pro-1.5                 55.56         26.24              42.91
# GPT-4o                         55.10         19.00              58.41
# LLaVA v1.6 34B                 40.56         13.74              13.63
# Claude-3.5-sonnet              55.56         38.70              49.82
# Gemini-flash-1.5               53.64         24.58              42.85
# Claude-3-haiku                 36.06         31.24              29.83
#
#                                                                         \
#
#                                                       Invasive Species
#                   Bean Leaf Lesions Soybean Diseases Dangerous Insects
# Model
# Gemini-pro-1.5                77.22            21.78             82.67
# GPT-4o                        65.92             3.70             82.79
# LLaVA v1.6 34B                44.03             8.54             18.54
# Claude-3.5-sonnet             68.65             8.54             82.02
# Gemini-flash-1.5              70.61            14.41             80.38
# Claude-3-haiku                55.26            12.69             51.28
#
#                             Classification (C)                               \
#                                           NMAE
#                               Disease Severity Stress Tolerance
#                   DeepWeeds     Yellow Rust 19              IDC FUSARIUM 22
# Model
# Gemini-pro-1.5        46.83              26.25            30.87       33.00
# GPT-4o                38.77              17.19            18.88       37.00
# LLaVA v1.6 34B         8.68              35.94            25.51       30.60
# Claude-3.5-sonnet     18.85              22.29            26.28       18.25
# Gemini-flash-1.5      32.83              31.25            19.39       24.00
# Claude-3-haiku        13.86              37.08            22.86       25.75
#
#                   Quantification (Q)
#                                 NMAE
#                                 Pest  Disease
#                          InsectCount PlantDoc
# Model
# Gemini-pro-1.5                 29.00     9.57
# GPT-4o                         15.80    18.14
# LLaVA v1.6 34B                 26.19    41.72
# Claude-3.5-sonnet              16.25    15.59
# Gemini-flash-1.5               16.32    21.22
# Claude-3-haiku                 28.34    22.14
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
#                   Identification (I)                                   \
#                                   F1
#                      Seed Morphology                    Foliar Stress
#                          Durum Wheat Soybean Seeds Mango Leaf Disease
# Model
# Gemini-pro-1.5                 63.44         30.63              41.24
# GPT-4o                         75.00         28.48              63.40
# LLaVA v1.6 34B                 32.77         20.48              10.63
# Claude-3.5-sonnet              55.56         44.62              52.80
# Gemini-flash-1.5               64.64         30.93              44.80
# Claude-3-haiku                 42.12         28.21              26.90
#
#                                                                         \
#
#                                                       Invasive Species
#                   Bean Leaf Lesions Soybean Diseases Dangerous Insects
# Model
# Gemini-pro-1.5                75.30            22.93             80.33
# GPT-4o                        78.77            20.37             83.59
# LLaVA v1.6 34B                39.54             8.94             10.70
# Claude-3.5-sonnet             67.18             9.57             78.19
# Gemini-flash-1.5              68.26            19.30             81.01
# Claude-3-haiku                48.11             7.96             50.78
#
#                             Classification (C)                               \
#                                           NMAE
#                               Disease Severity Stress Tolerance
#                   DeepWeeds     Yellow Rust 19              IDC FUSARIUM 22
# Model
# Gemini-pro-1.5        38.54              17.71            23.47       23.00
# GPT-4o                46.98              18.75            15.10       21.00
# LLaVA v1.6 34B        12.67              35.76            60.82       41.20
# Claude-3.5-sonnet     20.55              18.96            24.74       15.00
# Gemini-flash-1.5      29.85              26.25            24.23       24.25
# Claude-3-haiku        15.49              34.58            23.27       32.00
#
#                   Quantification (Q)
#                                 NMAE
#                                 Pest  Disease
#                          InsectCount PlantDoc
# Model
# Gemini-pro-1.5                 22.73    12.39
# GPT-4o                          9.55    12.99
# LLaVA v1.6 34B                 15.06    31.34
# Claude-3.5-sonnet              11.23    14.95
# Gemini-flash-1.5               11.93    14.35
# Claude-3-haiku                 17.84    17.69
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
#                   Identification (I)                                   \
#                                   F1
#                      Seed Morphology                    Foliar Stress
#                          Durum Wheat Soybean Seeds Mango Leaf Disease
# Model
# Gemini-pro-1.5                 74.03         37.37              52.81
# GPT-4o                         85.19         38.35              63.11
# LLaVA v1.6 34B                 35.72         19.15              15.89
# Claude-3.5-sonnet              77.76         48.68              49.23
# Gemini-flash-1.5               61.04         30.19              47.14
# Claude-3-haiku                 32.99         30.23              28.17
#
#                                                                         \
#
#                                                       Invasive Species
#                   Bean Leaf Lesions Soybean Diseases Dangerous Insects
# Model
# Gemini-pro-1.5                74.66            23.23             83.69
# GPT-4o                        72.72            59.26             82.18
# LLaVA v1.6 34B                38.72            13.38             23.60
# Claude-3.5-sonnet             73.55             8.23             84.20
# Gemini-flash-1.5              62.79            13.58             78.62
# Claude-3-haiku                58.08             4.56             54.51
#
#                             Classification (C)                               \
#                                           NMAE
#                               Disease Severity Stress Tolerance
#                   DeepWeeds     Yellow Rust 19              IDC FUSARIUM 22
# Model
# Gemini-pro-1.5        47.23              20.00            23.72       20.50
# GPT-4o                39.87              20.00            18.11       22.50
# LLaVA v1.6 34B         5.42              36.46            47.35       32.00
# Claude-3.5-sonnet     23.59              16.46            19.90       20.00
# Gemini-flash-1.5      33.76              24.38            21.17       26.00
# Claude-3-haiku        14.15              40.83            21.02       28.25
#
#                   Quantification (Q)
#                                 NMAE
#                                 Pest  Disease
#                          InsectCount PlantDoc
# Model
# Gemini-pro-1.5                 20.64    12.29
# GPT-4o                          7.57    13.12
# LLaVA v1.6 34B                 16.13    29.51
# Claude-3.5-sonnet              10.05    13.92
# Gemini-flash-1.5                9.18    13.92
# Claude-3-haiku                 16.71    15.90
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
#                   Identification (I)                                   \
#                                   F1
#                      Seed Morphology                    Foliar Stress
#                          Durum Wheat Soybean Seeds Mango Leaf Disease
# Model
# Gemini-pro-1.5                 77.45         38.12              47.11
# GPT-4o                         92.89         39.16              63.33
# LLaVA v1.6 34B                 32.73         22.70              20.02
# Claude-3.5-sonnet              79.07         48.23              54.72
# Gemini-flash-1.5               70.65         34.51              49.21
# Claude-3-haiku                 42.27         34.25              39.24
#
#                                                                         \
#
#                                                       Invasive Species
#                   Bean Leaf Lesions Soybean Diseases Dangerous Insects
# Model
# Gemini-pro-1.5                74.15            26.13             86.53
# GPT-4o                        85.80            24.07             85.52
# LLaVA v1.6 34B                38.26            11.73             19.02
# Claude-3.5-sonnet             78.50            14.51             82.59
# Gemini-flash-1.5              75.76            15.96             77.74
# Claude-3-haiku                45.50            11.48             52.15
#
#                             Classification (C)                               \
#                                           NMAE
#                               Disease Severity Stress Tolerance
#                   DeepWeeds     Yellow Rust 19              IDC FUSARIUM 22
# Model
# Gemini-pro-1.5        46.76              18.33            14.03       16.25
# GPT-4o                47.93              19.79            13.47       19.50
# LLaVA v1.6 34B        11.87              34.20            60.82       42.00
# Claude-3.5-sonnet     22.61              17.71            16.07       17.00
# Gemini-flash-1.5      42.53              24.38            18.37       19.00
# Claude-3-haiku        16.47              28.99            26.33       26.25
#
#                   Quantification (Q)
#                                 NMAE
#                                 Pest  Disease
#                          InsectCount PlantDoc
# Model
# Gemini-pro-1.5                 15.82    14.65
# GPT-4o                          6.36    10.96
# LLaVA v1.6 34B                 14.74    31.68
# Claude-3.5-sonnet               7.32    13.09
# Gemini-flash-1.5                6.25    14.80
# Claude-3-haiku                 17.64    18.77
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
# Processing Durum Wheat...
# Processing Soybean Seeds...
# Processing Mango Leaf Disease...
# Processing Bean Leaf Lesions...
# Processing Soybean Diseases...
# Processing Dangerous Insects...
# Processing DeepWeeds...
# Processing Yellow Rust 19...
# Processing IDC...
# Processing FUSARIUM 22...
# Processing InsectCount...
# Processing PlantDoc...
#                   Identification (I)                                   \
#                                   F1
#                      Seed Morphology                    Foliar Stress
#                          Durum Wheat Soybean Seeds Mango Leaf Disease
# Model
# Gemini-pro-1.5                 79.66         52.19              71.68
# GPT-4o                         95.94         48.29              80.96
# LLaVA v1.6 34B                 46.80         23.10              22.84
# Claude-3.5-sonnet              89.66         51.17              61.68
# Gemini-flash-1.5               83.70         48.09              64.66
# Claude-3-haiku                 53.29         38.02              38.92
#
#                                                                         \
#
#                                                       Invasive Species
#                   Bean Leaf Lesions Soybean Diseases Dangerous Insects
# Model
# Gemini-pro-1.5                78.17            24.41             82.98
# GPT-4o                        86.90            62.96             82.56
# LLaVA v1.6 34B                48.50            10.53             12.08
# Claude-3.5-sonnet             84.78            11.07             81.89
# Gemini-flash-1.5              73.42            23.67             82.72
# Claude-3-haiku                46.42             8.81             45.08
#
#                             Classification (C)                               \
#                                           NMAE
#                               Disease Severity Stress Tolerance
#                   DeepWeeds     Yellow Rust 19              IDC FUSARIUM 22
# Model
# Gemini-pro-1.5        49.96              17.08            12.04       17.00
# GPT-4o                56.03              15.83            60.82       19.75
# LLaVA v1.6 34B        13.23              30.56            60.82       60.00
# Claude-3.5-sonnet     27.17              16.04            16.84       14.00
# Gemini-flash-1.5      41.89              20.83            15.56       17.50
# Claude-3-haiku        15.34              25.69            23.06       21.75
#
#                   Quantification (Q)
#                                 NMAE
#                                 Pest  Disease
#                          InsectCount PlantDoc
# Model
# Gemini-pro-1.5                  9.57    13.04
# GPT-4o                          6.84    10.93
# LLaVA v1.6 34B                 13.18    26.28
# Claude-3.5-sonnet               5.75    11.31
# Gemini-flash-1.5                6.11    12.92
# Claude-3-haiku                 19.16    17.57

# %%
# display all columns without wrapping
# pd.set_option('display.max_columns', None)
pd.set_option('display.width', 150)
print ("0-shot results are:")
print(result_table_dict[0])
print ("8-shot results are:")
print(result_table_dict[8])
# Out:
# 0-shot results are:
#                   Identification (I)                                                                                                  \
#                                   F1
#                      Seed Morphology                    Foliar Stress                                     Invasive Species
#                          Durum Wheat Soybean Seeds Mango Leaf Disease Bean Leaf Lesions Soybean Diseases Dangerous Insects DeepWeeds
# Model
# Gemini-pro-1.5                55.560        26.240             42.910            77.220           21.780            82.670    46.830
# GPT-4o                        55.100        19.000             58.410            65.920            3.700            82.790    38.770
# LLaVA v1.6 34B                40.560        13.740             13.630            44.030            8.540            18.540     8.680
# Claude-3.5-sonnet             55.560        38.700             49.820            68.650            8.540            82.020    18.850
# Gemini-flash-1.5              53.640        24.580             42.850            70.610           14.410            80.380    32.830
# Claude-3-haiku                36.060        31.240             29.830            55.260           12.690            51.280    13.860
#
#                   Classification (C)                              Quantification (Q)
#                                 NMAE                                            NMAE
#                     Disease Severity Stress Tolerance                           Pest  Disease
#                       Yellow Rust 19              IDC FUSARIUM 22        InsectCount PlantDoc
# Model
# Gemini-pro-1.5                26.250           30.870      33.000             29.000    9.570
# GPT-4o                        17.190           18.880      37.000             15.800   18.140
# LLaVA v1.6 34B                35.940           25.510      30.600             26.190   41.720
# Claude-3.5-sonnet             22.290           26.280      18.250             16.250   15.590
# Gemini-flash-1.5              31.250           19.390      24.000             16.320   21.220
# Claude-3-haiku                37.080           22.860      25.750             28.340   22.140
# 8-shot results are:
#                   Identification (I)                                                                                                  \
#                                   F1
#                      Seed Morphology                    Foliar Stress                                     Invasive Species
#                          Durum Wheat Soybean Seeds Mango Leaf Disease Bean Leaf Lesions Soybean Diseases Dangerous Insects DeepWeeds
# Model
# Gemini-pro-1.5                79.660        52.190             71.680            78.170           24.410            82.980    49.960
# GPT-4o                        95.940        48.290             80.960            86.900           62.960            82.560    56.030
# LLaVA v1.6 34B                46.800        23.100             22.840            48.500           10.530            12.080    13.230
# Claude-3.5-sonnet             89.660        51.170             61.680            84.780           11.070            81.890    27.170
# Gemini-flash-1.5              83.700        48.090             64.660            73.420           23.670            82.720    41.890
# Claude-3-haiku                53.290        38.020             38.920            46.420            8.810            45.080    15.340
#
#                   Classification (C)                              Quantification (Q)
#                                 NMAE                                            NMAE
#                     Disease Severity Stress Tolerance                           Pest  Disease
#                       Yellow Rust 19              IDC FUSARIUM 22        InsectCount PlantDoc
# Model
# Gemini-pro-1.5                17.080           12.040      17.000              9.570   13.040
# GPT-4o                        15.830           60.820      19.750              6.840   10.930
# LLaVA v1.6 34B                30.560           60.820      60.000             13.180   26.280
# Claude-3.5-sonnet             16.040           16.840      14.000              5.750   11.310
# Gemini-flash-1.5              20.830           15.560      17.500              6.110   12.920
# Claude-3-haiku                25.690           23.060      21.750             19.160   17.570

# %%
# Print average score with respect to each model for identification
print("Average score with respect to each model for identification \n-- F1")
print(result_table_dict[0].loc[:, result_table_dict[0].columns.get_level_values(0) == 'Identification (I)'].mean(axis=1))
# now for rest of the dataset i.e classification and quantification combined
print("Average score with respect to each model for classification and quantification combined \n-- NMAE")
print(result_table_dict[0].loc[:, result_table_dict[0].columns.get_level_values(0).isin(['Classification (C)', 'Quantification (Q)'])].mean(axis=1))
# Out:
# Average score with respect to each model for identification
# -- F1
# Model
# Gemini-pro-1.5      50.459
# GPT-4o              46.241
# LLaVA v1.6 34B      21.103
# Claude-3.5-sonnet   46.020
# Gemini-flash-1.5    45.614
# Claude-3-haiku      32.889
# dtype: float64
# Average score with respect to each model for classification and quantification combined
# -- NMAE
# Model
# Gemini-pro-1.5      25.738
# GPT-4o              21.402
# LLaVA v1.6 34B      31.992
# Claude-3.5-sonnet   19.732
# Gemini-flash-1.5    22.436
# Claude-3-haiku      27.234
# dtype: float64

# %%
# # # # GOOD. DON'T DELETE

# import pandas as pd

# # Assuming your DataFrame is called 'result_table'
# result_table=result_table_dict[0]
# def to_latex_with_multicolumn(df):
#     latex = df.to_latex(multicolumn=True, multicolumn_format='c', multirow=True,
#                         column_format='l' + 'c'*len(df.columns), 
#                         float_format="{:0.2f}".format,
#                         escape=False)
    
#     # Remove the \toprule, \midrule, and \bottomrule commands
#     latex = latex.replace('\\toprule', '\\hline')
#     latex = latex.replace('\\midrule', '\\hline')
#     latex = latex.replace('\\bottomrule', '\\hline')
    
#     return latex

# # Convert to LaTeX
# latex_table = to_latex_with_multicolumn(result_table)

# # Add caption and label
# latex_table = """\\begin{table*}[htbp]
# \\centering
# \\caption{0-shot Performance of Large Language Models on Agricultural Image Datasets}
# \\label{tab:zero_shot_results}
# \\resizebox{\\textwidth}{!}{%
# """ + latex_table + "}\\end{table*}"

# print(latex_table)

# %%
# import pandas as pd

# # Assuming your DataFrame is called 'result_table'
# result_table = result_table_dict[8]

# def to_latex_with_multicolumn(df):
#     latex = df.to_latex(multicolumn=True, multicolumn_format='c', multirow=True,
#                         column_format='l' + 'c'*len(df.columns), 
#                         float_format="{:0.2f}".format,
#                         escape=False)
    
#     # Remove the \toprule, \midrule, and \bottomrule commands
#     latex = latex.replace('\\toprule', '\\hline')
#     latex = latex.replace('\\midrule', '\\hline')
#     latex = latex.replace('\\bottomrule', '\\hline')
    
#     # Remove the first two rows
#     lines = latex.split('\n')
#     lines = lines[:2] + lines[4:]  # Keep the first two lines (begin{tabular} and hline), then skip two rows
#     latex = '\n'.join(lines)
    
#     return latex

# # Split the DataFrame
# identification_columns = result_table.columns.get_level_values(0) == 'Identification (I)'
# identification_table = result_table.loc[:, identification_columns]

# classification_quantification_columns = result_table.columns.get_level_values(0).isin(['Classification (C)', 'Quantification (Q)'])
# classification_quantification_table = result_table.loc[:, classification_quantification_columns]

# # Convert to LaTeX
# latex_table_identification = to_latex_with_multicolumn(identification_table)
# latex_table_classification_quantification = to_latex_with_multicolumn(classification_quantification_table)

# # Combine the tables into a single table with subtables
# combined_latex_table = """\\begin{table*}[htbp]
# \\centering
# \\caption{8-shot Performance of Large Language Models on AgEval Benchmark}
# \\label{tab:eight_shot_results}

# \\begin{subtable}{1\\textwidth}
# \\centering
# {\\fontsize{7pt}{8pt}\\selectfont
# """ + latex_table_identification + """}
# \\caption{Identification - Metric: F1 Score (Higher is Better)}
# \\label{tab:eight_shot_results_identification}
# \\end{subtable}

# \\bigskip

# \\begin{subtable}{1\\textwidth}
# \\centering
# {\\fontsize{7pt}{8pt}\\selectfont
# """ + latex_table_classification_quantification + """}
# \\caption{Classification and Quantification - Metric: NMSE (Lower is Better)}
# \\label{tab:eight_shot_results_classification_quantification}
# \\end{subtable}

# \\end{table*}"""

# print(combined_latex_table)

# %% [markdown]
# # previous with color highlighting

# %%
import pandas as pd
import numpy as np

# Assuming your DataFrame is called 'result_table'
result_table = result_table_dict[0]

def highlight_max_values(s):
    is_max = s == s.max()
    is_second_max = s == s.nlargest(2).min()
    return ['\\cellcolor{yellow!25}' if v else '\\cellcolor{gray!25}' if s else '' for v, s in zip(is_max, is_second_max)]

def highlight_min_values(s):
    is_min = s == s.min()
    is_second_min = s == s.nsmallest(2).max()
    return ['\\cellcolor{yellow!25}' if v else '\\cellcolor{gray!25}' if s else '' for v, s in zip(is_min, is_second_min)]

def to_latex_with_multicolumn(df, highlight_function):
    # Create a copy of the DataFrame to avoid modifying the original
    df_highlighted = df.copy()

    # Apply highlighting to each column
    for col in df_highlighted.columns:
        if df_highlighted[col].dtype in [np.float64, np.int64]:
            highlights = highlight_function(df_highlighted[col])
            df_highlighted[col] = df_highlighted[col].astype(str).radd(highlights)

    latex = df_highlighted.to_latex(multicolumn=True, multicolumn_format='c', multirow=True,
                        column_format='l' + 'c'*len(df_highlighted.columns), 
                        float_format="{:0.2f}".format,
                        escape=False)
    
    # Remove the \toprule, \midrule, and \bottomrule commands
    latex = latex.replace('\\toprule', '\\hline')
    latex = latex.replace('\\midrule', '\\hline')
    latex = latex.replace('\\bottomrule', '\\hline')
    
    # Remove the first two rows
    lines = latex.split('\n')
    lines = lines[:2] + lines[4:]  # Keep the first two lines (begin{tabular} and hline), then skip two rows
    latex = '\n'.join(lines)
    
    return latex

# Split the DataFrame
identification_columns = result_table.columns.get_level_values(0) == 'Identification (I)'
identification_table = result_table.loc[:, identification_columns]

classification_quantification_columns = result_table.columns.get_level_values(0).isin(['Classification (C)', 'Quantification (Q)'])
classification_quantification_table = result_table.loc[:, classification_quantification_columns]

# Convert to LaTeX
latex_table_identification = to_latex_with_multicolumn(identification_table, highlight_max_values)
latex_table_classification_quantification = to_latex_with_multicolumn(classification_quantification_table, highlight_min_values)

# Combine the tables into a single table with subtables
combined_latex_table = """\\begin{table*}[htbp]
\\centering
\\caption{0-shot Performance of Large Language Models on AgEval Benchmark}
\\label{tab:zero_shot_results}

\\begin{subtable}{1\\textwidth}
\\centering
{\\fontsize{7pt}{8pt}\\selectfont
""" + latex_table_identification + """}
\\caption{Identification - Metric: F1 Score (Higher is Better). 
\\protect\\colorbox{yellow!25}{\\strut Highest} 
\\protect\\colorbox{gray!25}{\\strut Second Highest}}
\\label{tab:zero_shot_results_identification}
\\end{subtable}

\\bigskip

\\begin{subtable}{1\\textwidth}
\\centering
{\\fontsize{7pt}{8pt}\\selectfont
""" + latex_table_classification_quantification + """}
\\caption{Classification and Quantification - Metric: NMAE (Lower is Better). 
\\protect\\colorbox{yellow!25}{\\strut Lowest} 
\\protect\\colorbox{gray!25}{\\strut Second Lowest}}
\\label{tab:zero_shot_results_classification_quantification}
\\end{subtable}

\\end{table*}"""

print(combined_latex_table)
# Out:
# \begin{table*}[htbp]
# \centering
# \caption{0-shot Performance of Large Language Models on AgEval Benchmark}
# \label{tab:zero_shot_results}
#
# \begin{subtable}{1\textwidth}
# \centering
# {\fontsize{7pt}{8pt}\selectfont
# \begin{tabular}{lccccccc}
# \hline
#  & \multicolumn{2}{c}{Seed Morphology} & \multicolumn{3}{c}{Foliar Stress} & \multicolumn{2}{c}{Invasive Species} \\
#  & Durum Wheat & Soybean Seeds & Mango Leaf Disease & Bean Leaf Lesions & Soybean Diseases & Dangerous Insects & DeepWeeds \\
# Model &  &  &  &  &  &  &  \\
# \hline
# Gemini-pro-1.5 & \cellcolor{yellow!25}55.56 & 26.24 & 42.91 & \cellcolor{yellow!25}77.22 & \cellcolor{yellow!25}21.78 & \cellcolor{gray!25}82.67 & \cellcolor{yellow!25}46.83 \\
# GPT-4o & 55.1 & 19.0 & \cellcolor{yellow!25}58.41 & 65.92 & 3.7 & \cellcolor{yellow!25}82.79 & \cellcolor{gray!25}38.77 \\
# LLaVA v1.6 34B & 40.56 & 13.74 & 13.63 & 44.03 & 8.54 & 18.54 & 8.68 \\
# Claude-3.5-sonnet & \cellcolor{yellow!25}55.56 & \cellcolor{yellow!25}38.7 & \cellcolor{gray!25}49.82 & 68.65 & 8.54 & 82.02 & 18.85 \\
# Gemini-flash-1.5 & 53.64 & 24.58 & 42.85 & \cellcolor{gray!25}70.61 & \cellcolor{gray!25}14.41 & 80.38 & 32.83 \\
# Claude-3-haiku & 36.06 & \cellcolor{gray!25}31.24 & 29.83 & 55.26 & 12.69 & 51.28 & 13.86 \\
# \hline
# \end{tabular}
# }
# \caption{Identification - Metric: F1 Score (Higher is Better).
# \protect\colorbox{yellow!25}{\strut Highest}
# \protect\colorbox{gray!25}{\strut Second Highest}}
# \label{tab:zero_shot_results_identification}
# \end{subtable}
#
# \bigskip
#
# \begin{subtable}{1\textwidth}
# \centering
# {\fontsize{7pt}{8pt}\selectfont
# \begin{tabular}{lccccc}
# \hline
#  & Disease Severity & \multicolumn{2}{c}{Stress Tolerance} & Pest & Disease \\
#  & Yellow Rust 19 & IDC & FUSARIUM 22 & InsectCount & PlantDoc \\
# Model &  &  &  &  &  \\
# \hline
# Gemini-pro-1.5 & 26.25 & 30.87 & 33.0 & 29.0 & \cellcolor{yellow!25}9.57 \\
# GPT-4o & \cellcolor{yellow!25}17.19 & \cellcolor{yellow!25}18.88 & 37.0 & \cellcolor{yellow!25}15.8 & 18.14 \\
# LLaVA v1.6 34B & 35.94 & 25.51 & 30.6 & 26.19 & 41.72 \\
# Claude-3.5-sonnet & \cellcolor{gray!25}22.29 & 26.28 & \cellcolor{yellow!25}18.25 & \cellcolor{gray!25}16.25 & \cellcolor{gray!25}15.59 \\
# Gemini-flash-1.5 & 31.25 & \cellcolor{gray!25}19.39 & \cellcolor{gray!25}24.0 & 16.32 & 21.22 \\
# Claude-3-haiku & 37.08 & 22.86 & 25.75 & 28.34 & 22.14 \\
# \hline
# \end{tabular}
# }
# \caption{Classification and Quantification - Metric: NMSE (Lower is Better).
# \protect\colorbox{yellow!25}{\strut Lowest}
# \protect\colorbox{gray!25}{\strut Second Lowest}}
# \label{tab:zero_shot_results_classification_quantification}
# \end{subtable}
#
# \end{table*}

# %%
import pandas as pd
import numpy as np

def calculate_ranks_and_mrr(df):
    def rank_column(col):
        if col.name[0] in ['Classification (C)', 'Quantification (Q)']:
            return col.rank()  # Lower is better for these categories
        else:
            return col.rank(ascending=False)  # Higher is better for Identification

    # Calculate ranks for each dataset
    ranks = df.apply(rank_column)

    # Separate ranks for Identification and Classification+Quantification
    id_ranks = ranks.loc[:, ranks.columns.get_level_values(0) == 'Identification (I)']
    cq_ranks = ranks.loc[:, ranks.columns.get_level_values(0).isin(['Classification (C)', 'Quantification (Q)'])]

    # Calculate MRR for each category
    mrr_id = (1 / id_ranks).mean(axis=1)
    mrr_cq = (1 / cq_ranks).mean(axis=1)

    # Calculate average ranks
    avg_rank_id = id_ranks.mean(axis=1)
    avg_rank_cq = cq_ranks.mean(axis=1)

    return pd.DataFrame({
        'Avg Rank (ID)': avg_rank_id,
        'MRR (ID)': mrr_id,
        'Avg Rank (CQ)': avg_rank_cq,
        'MRR (CQ)': mrr_cq
    })

# Calculate metrics for 0-shot and 8-shot
results_0shot = calculate_ranks_and_mrr(result_table_dict[0])
results_8shot = calculate_ranks_and_mrr(result_table_dict[8])

# Combine results into a single DataFrame
combined_results = pd.concat([
    results_0shot.add_suffix(' (0-shot)'),
    results_8shot.add_suffix(' (8-shot)')
], axis=1)

# Sort the DataFrame by the average of 8-shot MRR scores
combined_results['Avg 8-shot MRR'] = (combined_results['MRR (ID) (8-shot)'] + combined_results['MRR (CQ) (8-shot)']) / 2
combined_results = combined_results.sort_values('Avg 8-shot MRR', ascending=False)

# Reorder columns
column_order = [
    'Avg Rank (ID) (0-shot)', 'MRR (ID) (0-shot)', 'Avg Rank (CQ) (0-shot)', 'MRR (CQ) (0-shot)',
    'Avg Rank (ID) (8-shot)', 'MRR (ID) (8-shot)', 'Avg Rank (CQ) (8-shot)', 'MRR (CQ) (8-shot)',
    'Avg 8-shot MRR'
]
combined_results = combined_results[column_order]

# Format the DataFrame
pd.set_option('display.float_format', '{:.3f}'.format)
print(combined_results)
# Out:
#                    Avg Rank (ID) (0-shot)  MRR (ID) (0-shot)  Avg Rank (CQ) (0-shot)  MRR (CQ) (0-shot)  Avg Rank (ID) (8-shot)  MRR (ID) (8-shot)  \
# Model
# GPT-4o                              3.143              0.493                   2.400              0.700                   1.571              0.810
# Gemini-pro-1.5                      1.786              0.690                   4.200              0.373                   2.143              0.583
# Claude-3.5-sonnet                   2.714              0.472                   2.400              0.540                   3.143              0.357
# Gemini-flash-1.5                    3.286              0.333                   3.000              0.367                   3.143              0.333
# Claude-3-haiku                      4.429              0.257                   4.400              0.247                   5.286              0.190
# LLaVA v1.6 34B                      5.643              0.179                   4.600              0.223                   5.714              0.176
#
#                    Avg Rank (CQ) (8-shot)  MRR (CQ) (8-shot)  Avg 8-shot MRR
# Model
# GPT-4o                              2.900              0.553           0.681
# Gemini-pro-1.5                      2.800              0.467           0.525
# Claude-3.5-sonnet                   1.800              0.667           0.512
# Gemini-flash-1.5                    2.800              0.383           0.358
# Claude-3-haiku                      5.000              0.203           0.197
# LLaVA v1.6 34B                      5.700              0.176           0.176

# %% [markdown]
# # plotting MRR

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({
    'font.family': 'Arial',
    'font.size': 8,
    'axes.labelsize': 9,
    'axes.titlesize': 10,
    'xtick.labelsize': 7,
    'ytick.labelsize': 7,
    'legend.fontsize': 8,
})

def calculate_ranks_and_mrr(df):
    def rank_column(col):
        if col.name[0] in ['Classification (C)', 'Quantification (Q)']:
            return col.rank()  # Lower is better for these categories
        else:
            return col.rank(ascending=False)  # Higher is better for Identification

    ranks = df.apply(rank_column)
    id_ranks = ranks.loc[:, ranks.columns.get_level_values(0) == 'Identification (I)']
    cq_ranks = ranks.loc[:, ranks.columns.get_level_values(0).isin(['Classification (C)', 'Quantification (Q)'])]

    mrr_id = (1 / id_ranks).mean(axis=1)
    mrr_cq = (1 / cq_ranks).mean(axis=1)

    return pd.DataFrame({
        'MRR (ID)': mrr_id,
        'MRR (CQ)': mrr_cq
    })

# Calculate metrics for 0-shot and 8-shot
results_0shot = calculate_ranks_and_mrr(result_table_dict[0])
results_8shot = calculate_ranks_and_mrr(result_table_dict[8])

def plot_performance(data, shot):
    fig, ax = plt.subplots(figsize=(4, 3))
    bar_width = 0.35
    opacity = 0.8

    index = np.arange(len(data.index))
    
    ax.bar(index - bar_width/2, data['MRR (ID)'], bar_width,
           alpha=opacity, color='skyblue', label='Identification')
    ax.bar(index + bar_width/2, data['MRR (CQ)'], bar_width,
           alpha=opacity, color='lightgreen', label='Classification & Quantification')

    ax.set_xlabel('Models')
    ax.set_ylabel('Mean Reciprocal Rank (MRR)')
    ax.set_title(f'{shot}-shot Performance')
    ax.set_xticks(index)
    ax.set_xticklabels(data.index, rotation=45, ha='right')
    ax.legend(loc='upper right')#, bbox_to_anchor=(0, 1.02))

    # Set y-axis limits based on the data
    y_min = min(data['MRR (ID)'].min(), data['MRR (CQ)'].min())
    y_max = max(data['MRR (ID)'].max(), data['MRR (CQ)'].max())
    ax.set_ylim(max(0, y_min - 0.1), min(1, y_max + 0.1))

    plt.tight_layout()
    plt.savefig(f'analysis/overall-performance/{shot}_shot.pdf', dpi=300, bbox_inches='tight')
    plt.close()

# Sort models by average MRR across all categories for 8-shot
avg_mrr_8shot = results_8shot.mean(axis=1)
model_order = avg_mrr_8shot.sort_values(ascending=False).index

# Plot 0-shot performance
plot_performance(results_0shot.loc[model_order], '0')

# Plot 8-shot performance
plot_performance(results_8shot.loc[model_order], '8')

print("Plots have been generated and saved.")
# Out:
# Plots have been generated and saved.

# %% [markdown]
# # Radar Plot

# %% [markdown]
# # Radar fixed size

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams.update({
    'font.family': 'Arial',
    'font.size': 13,
    'axes.labelsize': 13,
    'axes.titlesize': 14,
    'xtick.labelsize': 11,
    'ytick.labelsize': 11,
    'legend.fontsize': 12,
})

# Create a single figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(13, 4), subplot_kw=dict(projection='polar'))

for idx, shot in enumerate([0, 2, 8]):
    result_table = result_table_dict[shot]
    
    # Prepare the data
    models = result_table.index.tolist()
    datasets = result_table.columns.get_level_values(3).tolist()
    metrics = result_table.columns.get_level_values(1).tolist()
    values = result_table.values

    # Normalize the values based on the metric
    normalized_values = np.zeros_like(values)
    for i, metric in enumerate(metrics):
        if metric == 'F1':
            normalized_values[:, i] = values[:, i] 
        elif metric == 'NMAE':
            normalized_values[:, i] = 100-values[:, i]

    # Remove columns with all NaN values
    valid_columns = ~np.all(np.isnan(normalized_values), axis=0)
    normalized_values = normalized_values[:, valid_columns]
    datasets = [d for d, v in zip(datasets, valid_columns) if v]

    # Set up the angles for each dataset
    angles = np.linspace(0, 2*np.pi, len(datasets), endpoint=False)

    # Close the plot by appending the first value to the end
    normalized_values = np.concatenate((normalized_values, normalized_values[:, [0]]), axis=1)
    angles = np.concatenate((angles, [angles[0]]))

    ax = axs[idx]
    
    # Color cycle for the models
    colors = plt.cm.tab10(np.linspace(0, 1, len(models)))
    ax.set_ylim(0, 100)  # Set the range from 0 to 100

    # Plot each model
    for i, model in enumerate(models):
        ax.plot(angles, normalized_values[i], 'o-', linewidth=1, color=colors[i], label=model, markersize=3)
        ax.fill(angles, normalized_values[i], alpha=0.1, color=colors[i])

    # Set the labels
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(datasets)
    ax.tick_params(axis='both', which='major', pad=27)

    # Remove radial labels and set grid
    ax.set_yticklabels([])
    ax.grid(True, linestyle='--', alpha=0.7)
    
    ax.set_title(f'{shot}-shot')

# Create a single legend for all subplots
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', bbox_to_anchor=(0.5, -0.05), ncol=len(models))

# Adjust layout and save
plt.tight_layout()
plt.subplots_adjust(bottom=0.2)  # Make room for the legend
plt.savefig('analysis/radar_plots/combined.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
result_table_dict[8].head()
# Out:
#                   Identification (I)                                                                                                  \
#                                   F1
#                      Seed Morphology                    Foliar Stress                                     Invasive Species
#                          Durum Wheat Soybean Seeds Mango Leaf Disease Bean Leaf Lesions Soybean Diseases Dangerous Insects DeepWeeds
# Model
# Gemini-pro-1.5                79.660        52.190             71.680            78.170           24.410            82.980    49.960
# GPT-4o                        95.940        48.290             80.960            86.900           62.960            82.560    56.030
# LLaVA v1.6 34B                46.800        23.100             22.840            48.500           10.530            12.080    13.230
# Claude-3.5-sonnet             89.660        51.170             61.680            84.780           11.070            81.890    27.170
# Gemini-flash-1.5              83.700        48.090             64.660            73.420           23.670            82.720    41.890
#
#                   Classification (C)                              Quantification (Q)
#                                 NMAE                                            NMAE
#                     Disease Severity Stress Tolerance                           Pest  Disease
#                       Yellow Rust 19              IDC FUSARIUM 22        InsectCount PlantDoc
# Model
# Gemini-pro-1.5                17.080           12.040      17.000              9.570   13.040
# GPT-4o                        15.830           60.820      19.750              6.840   10.930
# LLaVA v1.6 34B                30.560           60.820      60.000             13.180   26.280
# Claude-3.5-sonnet             16.040           16.840      14.000              5.750   11.310
# Gemini-flash-1.5              20.830           15.560      17.500              6.110   12.920

# %% [markdown]
# # Plots per Dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.gridspec as gridspec

# Set up the plot style
plt.rcParams.update({
    'font.family': 'Arial',
    'font.size': 13,
    'axes.labelsize': 13,
    'axes.titlesize': 14,
    'xtick.labelsize': 11,
    'ytick.labelsize': 11,
    'legend.fontsize': 12,
})

# Prepare data
shots = [0, 1, 2, 4, 8]
models = [model for model in result_table_dict[0].index if model not in ('LLaVA v1.6 34B', 'Claude-3-haiku')]
datasets = [dataset for dataset in result_table_dict[0].columns if dataset[3] != 'IP02']

# Set up the grid
n_datasets = len(datasets)
n_cols = 6  # Changed to 6 figures per row
n_rows = math.ceil(n_datasets / n_cols)

# Create the main figure
fig = plt.figure(figsize=(15, 2.5 * n_rows))  # Increased figure width

# Use GridSpec for more control over subplot positioning
gs = gridspec.GridSpec(n_rows, n_cols)

# Color palette for models
model_colors = sns.color_palette("husl", n_colors=len(models))

# Background colors for problem types (subtle for subplots)
bg_colors = {
    'Identification (I)': '#f0f0ff',
    'Classification (C)': '#fff0f0',
    'Quantification (Q)': '#f0fff0'
}

# Intense colors for problem types (for legend)
legend_colors = {
    'Identification (I)': '#8080ff',
    'Classification (C)': '#ff8080',
    'Quantification (Q)': '#80ff80'
}

# Plot each dataset
for i, dataset in enumerate(datasets):
    row = i // n_cols
    col = i % n_cols
    
    ax = fig.add_subplot(gs[row, col])
    
    ax.set_facecolor(bg_colors[dataset[0]])
    
    all_values = []
    for j, model in enumerate(models):
        values = [result_table_dict[shot].loc[model, dataset] for shot in shots]
        all_values.extend(values)
        ax.plot(shots, values, marker='o', markersize=3, linewidth=1, color=model_colors[j])
    
    ax.set_title(f'{dataset[3]}')
    ax.set_xlabel('Number of Shots')
    ax.set_ylabel(dataset[1])
    
    # Set y-axis limits dynamically
    y_min, y_max = min(all_values), max(all_values)
    y_range = y_max - y_min
    ax.set_ylim(y_min - 0.1 * y_range, y_max + 0.1 * y_range)

    # Add grid lines
    ax.grid(True, linestyle='--', alpha=0.5)
    
    # Set x-axis ticks
    ax.set_xticks(shots)

# Create a custom legend
legend_elements = [plt.Line2D([0], [0], color=model_colors[i], lw=1, label=model) 
                   for i, model in enumerate(models)]

# Add problem type legend with intense colors
problem_type_patches = [mpatches.Patch(facecolor=color, edgecolor='none', label=ptype) 
                        for ptype, color in legend_colors.items()]
legend_elements.extend(problem_type_patches)

fig.legend(handles=legend_elements, loc='upper center', bbox_to_anchor=(0.5, 1.02), 
           ncol=len(models) + len(bg_colors))

# Adjust the layout
plt.tight_layout()
plt.subplots_adjust(top=0.87, hspace=0.7, wspace=0.3)  # Make room for the legend and adjust spacing

# Save the figure
plt.savefig('analysis/individual_plots.pdf', bbox_inches='tight')
# Show the plot
plt.show()

# %% [markdown]
# # Plots per Classes (only for identification; classification will require calculate-metric function error handling)

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

plt.rcParams.update({
    'font.family': 'Arial',
    'font.size': 12,
    'axes.labelsize': 12,
    'axes.titlesize': 13,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'legend.fontsize': 11,
})

def calculate_f1_scores(true_labels, pred_labels):
    classes = np.unique(true_labels)
    f1_scores = {}
    for cls in classes:
        true_binary = (true_labels == cls)
        pred_binary = (pred_labels == cls)
        f1 = f1_score(true_binary, pred_binary, zero_division=0)
        f1_scores[cls] = f1 * 100  # Scale to 0-100
    return f1_scores

# Get the list of model folders
model_folders = [f for f in os.listdir('results') if os.path.isdir(os.path.join('results', f))]

# Initialize results dictionary
results = {model: {} for model in model_folders}

# Process each dataset for each model
for model in model_folders:
    for dataset, (category, metric, subcategory) in dataset_mapping.items():
        if category == 'Quantification (Q)' or category == 'Classification (C)':
            continue  # Skip quantification for now
        try:
            df = pd.read_csv(f'results/{model}/{dataset}.csv', engine='python')
            true_labels = df['1'].fillna('Unknown').astype(str)
            zero_shot = df['# of Shots 0'].fillna('NA_placeholder').astype(str)
            eight_shot = df['# of Shots 8'].fillna('NA_placeholder').astype(str)
            
            f1_zero = calculate_f1_scores(true_labels, zero_shot)
            f1_eight = calculate_f1_scores(true_labels, eight_shot)
            
            # Sort categories by 0-shot F1 score
            sorted_zero = sorted(f1_zero.items(), key=lambda x: x[1], reverse=True)
            
            # Get highest, median, and lowest performing categories based on 0-shot
            n = len(sorted_zero)
            highest = sorted_zero[0][0]
            median = sorted_zero[n//2][0]
            lowest = sorted_zero[-1][0]
            
            results[model][dataset] = {
                '0-shot': {
                    'Highest': {'category': highest, 'score': f1_zero[highest]},
                    'Median': {'category': median, 'score': f1_zero[median]},
                    'Lowest': {'category': lowest, 'score': f1_zero[lowest]}
                },
                '8-shot': {
                    'Highest': {'category': highest, 'score': f1_eight[highest]},
                    'Median': {'category': median, 'score': f1_eight[median]},
                    'Lowest': {'category': lowest, 'score': f1_eight[lowest]}
                }
            }
        except Exception as e:
            print(f"Error processing {model}/{dataset}: {str(e)}")
            results[model][dataset] = {
                '0-shot': {
                    'Highest': {'category': 'N/A', 'score': np.nan},
                    'Median': {'category': 'N/A', 'score': np.nan},
                    'Lowest': {'category': 'N/A', 'score': np.nan}
                },
                '8-shot': {
                    'Highest': {'category': 'N/A', 'score': np.nan},
                    'Median': {'category': 'N/A', 'score': np.nan},
                    'Lowest': {'category': 'N/A', 'score': np.nan}
                }
            }

def create_plot(dataset, results):
    fig, ax = plt.subplots(figsize=(9.5, 4))
    bar_width = 0.15
    opacity = 0.8
    padding = 1  # 1% padding for empty or zero values

    performances = ['Highest', 'Median', 'Lowest']
    num_models = len(model_folders)
    
    for p_idx, performance in enumerate(performances):
        for m_idx, model in enumerate(model_folders):
            zero_shot = results[model][dataset]['0-shot'][performance]['score']
            eight_shot = results[model][dataset]['8-shot'][performance]['score']
            category = results[model][dataset]['0-shot'][performance]['category']
            
            x = p_idx * (num_models + 1) * bar_width + m_idx * bar_width
            
            # Add padding for empty or zero values
            zero_shot = max(zero_shot, padding) if not np.isnan(zero_shot) else padding
            eight_shot = max(eight_shot, padding) if not np.isnan(eight_shot) else padding
            
            ax.bar(x, zero_shot, bar_width, alpha=opacity, color=plt.cm.Set3(m_idx), 
                   label=model if p_idx == 0 else "", hatch='')
            ax.bar(x, eight_shot - zero_shot, bar_width, alpha=opacity, color=plt.cm.Set3(m_idx), 
                   hatch='/////', bottom=zero_shot)
        
        # Add category name
        x_center = p_idx * (num_models + 1) * bar_width + (num_models - 1) * bar_width / 2
        ax.text(x_center, -0.05, f"{performance}\n({category})", ha='center', va='top', transform=ax.get_xaxis_transform())

    ax.set_ylabel('F1 Score')
    ax.set_title(f'F1 Scores for {dataset}')
    ax.set_ylim(0, 105)  # Set y-axis limit to 105
    
    # Remove x-axis ticks
    ax.set_xticks([])
    
    # Add a legend for models
    legend = ax.legend(title="Models", bbox_to_anchor=(1.05, 1), loc='upper left')
    
    # Add clarification for 0-shot and 8-shot under the legend
    ax.text(1.05, 0, 'Solid: 0-shot F1 Score \n /////  : 8-shot Additional Gain in F1', transform=ax.transAxes, 
            verticalalignment='bottom', horizontalalignment='left')

    plt.tight_layout()
    plt.savefig(f'analysis/individual_bar_plots/{dataset}_f1_scores.pdf', dpi=300, bbox_inches='tight')
    # plt.show()
    plt.close()

# Generate plots
for dataset, (category, metric, subcategory) in dataset_mapping.items():
    if category == 'Quantification (Q)' or category == 'Classification (C)':
        continue
    create_plot(dataset, results)

print("Plots have been generated and saved.")
# Out:
#   Cell In[31], line 23
#     f1 = f1_score(true_binary, pred_binary, zero_division=0, average=)
#                                                                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## variation quantification

# %%
# # # # GOOD. DON'T DELETE

# import pandas as pd

# # Assuming your DataFrame is called 'result_table'
# result_table=result_table_dict[0]
# def to_latex_with_multicolumn(df):
#     latex = df.to_latex(multicolumn=True, multicolumn_format='c', multirow=True,
#                         column_format='l' + 'c'*len(df.columns), 
#                         float_format="{:0.2f}".format,
#                         escape=False)
    
#     # Remove the \toprule, \midrule, and \bottomrule commands
#     latex = latex.replace('\\toprule', '\\hline')
#     latex = latex.replace('\\midrule', '\\hline')
#     latex = latex.replace('\\bottomrule', '\\hline')
    
#     return latex

# # Convert to LaTeX
# latex_table = to_latex_with_multicolumn(result_table)

# # Add caption and label
# latex_table = """\\begin{table*}[htbp]
# \\centering
# \\caption{0-shot Performance of Large Language Models on Agricultural Image Datasets}
# \\label{tab:zero_shot_results}
# \\resizebox{\\textwidth}{!}{%
# """ + latex_table + "}\\end{table*}"

# print(latex_table)

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score

def calculate_f1_scores(true_labels, pred_labels):
    classes = np.unique(true_labels)
    f1_scores = {}
    for cls in classes:
        true_binary = (true_labels == cls)
        pred_binary = (pred_labels == cls)
        f1 = f1_score(true_binary, pred_binary, zero_division=0)
        f1_scores[cls] = f1 * 100  # Scale to 0-100
    return f1_scores

def coefficient_of_variation(data):
    return np.std(data) / np.mean(data) * 100 if np.mean(data) != 0 else 0

# Get the list of model folders, excluding "LLaVA v1.6 34B"
model_folders = [f for f in os.listdir('results') if os.path.isdir(os.path.join('results', f)) and f != "LLaVA v1.6 34B"]
print(f"Models analyzed: {model_folders}")

# Filter dataset_mapping for identification tasks only
identification_datasets = {k: v for k, v in dataset_mapping.items() if v[0] == 'Identification (I)'}
print(f"Identification datasets: {list(identification_datasets.keys())}")

# Initialize results dictionary
results = {model: {} for model in model_folders}

# Process each dataset for each model
for model in model_folders:
    for dataset in identification_datasets.keys():
        try:
            df = pd.read_csv(f'results/{model}/{dataset}.csv', engine='python')
            true_labels = df['1'].fillna('Unknown').astype(str)
            eight_shot = df['# of Shots 8'].fillna('NA_placeholder').astype(str)
            
            f1_scores = calculate_f1_scores(true_labels, eight_shot)
            
            cv = coefficient_of_variation(list(f1_scores.values()))
            avg_f1 = np.mean(list(f1_scores.values()))
            
            results[model][dataset] = {
                'cv': cv,
                'avg_f1': avg_f1
            }
            print(f"Processed {model} - {dataset}: CV = {cv:.2f}, Avg F1 = {avg_f1:.2f}")
        except Exception as e:
            print(f"Error processing {model}/{dataset}: {str(e)}")
            results[model][dataset] = {
                'cv': np.nan,
                'avg_f1': np.nan
            }

# Create the result table for CV
cv_table = pd.DataFrame({model: {dataset: data['cv'] for dataset, data in model_data.items()} 
                         for model, model_data in results.items()})

# Create the result table for average F1 scores
avg_f1_table = pd.DataFrame({model: {dataset: data['avg_f1'] for dataset, data in model_data.items()} 
                             for model, model_data in results.items()})

# Calculate and add average column (excluding the 'Model Avg' row if it exists)
cv_table['Dataset Avg'] = cv_table.mean(axis=1)
avg_f1_table['Dataset Avg'] = avg_f1_table.mean(axis=1)

# Calculate and add average row (excluding the 'Dataset Avg' column)
cv_table.loc['Model Avg'] = cv_table.iloc[:, :-1].mean()
avg_f1_table.loc['Model Avg'] = avg_f1_table.iloc[:, :-1].mean()

# Sort datasets and models by their average CV
dataset_order = cv_table['Dataset Avg'].iloc[:-1].sort_values(ascending=False).index
model_order = cv_table.loc['Model Avg'].iloc[:-1].sort_values(ascending=False).index

# Reorder the result tables
cv_table = cv_table.loc[list(dataset_order) + ['Model Avg'], list(model_order) + ['Dataset Avg']]
avg_f1_table = avg_f1_table.loc[list(dataset_order) + ['Model Avg'], list(model_order) + ['Dataset Avg']]

# Ensure 'Model Avg' for 'Dataset Avg' is calculated correctly
cv_table.loc['Model Avg', 'Dataset Avg'] = cv_table.loc['Model Avg', model_order].mean()
avg_f1_table.loc['Model Avg', 'Dataset Avg'] = avg_f1_table.loc['Model Avg', model_order].mean()

# Calculate and print overall statistics
overall_mean_cv = cv_table.iloc[:-1, :-1].mean().mean()
overall_std_cv = cv_table.iloc[:-1, :-1].std().std()
print(f"\nOverall mean CV for identification tasks: {overall_mean_cv:.2f}%")
print(f"Overall standard deviation of CV for identification tasks: {overall_std_cv:.2f}%")

# Print datasets ranked by average CV
print("\nDatasets ranked by average CV (most variable performance across classes):")
dataset_ranking = cv_table['Dataset Avg'].iloc[:-1].sort_values(ascending=False)
for dataset, score in dataset_ranking.items():
    print(f"{dataset}: {score:.2f}%")

# Print models ranked by average CV
print("\nModels ranked by average CV (most variable performance across datasets):")
model_ranking = cv_table.loc['Model Avg'].iloc[:-1].sort_values(ascending=False)
for model, score in model_ranking.items():
    print(f"{model}: {score:.2f}%")

# Identify the most challenging dataset (highest average CV)
most_challenging_dataset = dataset_ranking.index[0]
most_challenging_score = dataset_ranking.iloc[0]
print(f"\nMost challenging identification dataset: {most_challenging_dataset} (Average CV: {most_challenging_score:.2f}%)")

# Identify the easiest dataset (lowest average CV)
easiest_dataset = dataset_ranking.index[-1]
easiest_score = dataset_ranking.iloc[-1]
print(f"Easiest identification dataset: {easiest_dataset} (Average CV: {easiest_score:.2f}%)")

# Identify the most consistent model (lowest average CV)
most_consistent_model = model_ranking.index[-1]
most_consistent_score = model_ranking.iloc[-1]
print(f"\nMost consistent model: {most_consistent_model} (Average CV: {most_consistent_score:.2f}%)")

# Identify the least consistent model (highest average CV)
least_consistent_model = model_ranking.index[0]
least_consistent_score = model_ranking.iloc[0]
print(f"Least consistent model: {least_consistent_model} (Average CV: {least_consistent_score:.2f}%)")
# Out:
# Models analyzed: ['Gemini-pro-1.5', 'GPT-4o', 'Claude-3.5-sonnet', 'Gemini-flash-1.5', 'Claude-3-haiku']
# Identification datasets: ['Durum Wheat', 'Soybean Seeds', 'Mango Leaf Disease', 'Bean Leaf Lesions', 'Soybean Diseases', 'Dangerous Insects', 'DeepWeeds']
# Processed Gemini-pro-1.5 - Durum Wheat: CV = 16.74, Avg F1 = 79.66
# Processed Gemini-pro-1.5 - Soybean Seeds: CV = 28.85, Avg F1 = 52.19
# Processed Gemini-pro-1.5 - Mango Leaf Disease: CV = 39.87, Avg F1 = 71.68
# Processed Gemini-pro-1.5 - Bean Leaf Lesions: CV = 17.42, Avg F1 = 78.17
# Processed Gemini-pro-1.5 - Soybean Diseases: CV = 94.23, Avg F1 = 24.41
# Processed Gemini-pro-1.5 - Dangerous Insects: CV = 32.86, Avg F1 = 82.98
# Processed Gemini-pro-1.5 - DeepWeeds: CV = 49.06, Avg F1 = 49.96
# Processed GPT-4o - Durum Wheat: CV = 3.01, Avg F1 = 95.94
# Processed GPT-4o - Soybean Seeds: CV = 29.99, Avg F1 = 48.29
# Processed GPT-4o - Mango Leaf Disease: CV = 18.35, Avg F1 = 80.96
# Processed GPT-4o - Bean Leaf Lesions: CV = 5.95, Avg F1 = 86.90
# Processed GPT-4o - Soybean Diseases: CV = 72.52, Avg F1 = 62.96
# Processed GPT-4o - Dangerous Insects: CV = 23.56, Avg F1 = 82.56
# Processed GPT-4o - DeepWeeds: CV = 28.79, Avg F1 = 56.03
# Processed Claude-3.5-sonnet - Durum Wheat: CV = 8.43, Avg F1 = 89.66
# Processed Claude-3.5-sonnet - Soybean Seeds: CV = 31.30, Avg F1 = 51.17
# Processed Claude-3.5-sonnet - Mango Leaf Disease: CV = 35.71, Avg F1 = 61.68
# Processed Claude-3.5-sonnet - Bean Leaf Lesions: CV = 7.88, Avg F1 = 84.78
# Processed Claude-3.5-sonnet - Soybean Diseases: CV = 68.64, Avg F1 = 11.07
# Processed Claude-3.5-sonnet - Dangerous Insects: CV = 25.23, Avg F1 = 81.89
# Processed Claude-3.5-sonnet - DeepWeeds: CV = 46.79, Avg F1 = 27.17
# Processed Gemini-flash-1.5 - Durum Wheat: CV = 13.94, Avg F1 = 83.70
# Processed Gemini-flash-1.5 - Soybean Seeds: CV = 36.54, Avg F1 = 48.09
# Processed Gemini-flash-1.5 - Mango Leaf Disease: CV = 42.76, Avg F1 = 64.66
# Processed Gemini-flash-1.5 - Bean Leaf Lesions: CV = 19.13, Avg F1 = 73.42
# Processed Gemini-flash-1.5 - Soybean Diseases: CV = 86.44, Avg F1 = 23.67
# Processed Gemini-flash-1.5 - Dangerous Insects: CV = 28.82, Avg F1 = 82.72
# Processed Gemini-flash-1.5 - DeepWeeds: CV = 44.32, Avg F1 = 41.89
# Processed Claude-3-haiku - Durum Wheat: CV = 29.28, Avg F1 = 53.29
# Processed Claude-3-haiku - Soybean Seeds: CV = 40.76, Avg F1 = 38.02
# Processed Claude-3-haiku - Mango Leaf Disease: CV = 71.07, Avg F1 = 38.92
# Processed Claude-3-haiku - Bean Leaf Lesions: CV = 64.66, Avg F1 = 46.42
# Processed Claude-3-haiku - Soybean Diseases: CV = 84.61, Avg F1 = 8.81
# Processed Claude-3-haiku - Dangerous Insects: CV = 72.45, Avg F1 = 45.08
# Processed Claude-3-haiku - DeepWeeds: CV = 43.39, Avg F1 = 15.34
#
# Overall mean CV for identification tasks: 38.95%
# Overall standard deviation of CV for identification tasks: 2.43%
#
# Datasets ranked by average CV (most variable performance across classes):
# Soybean Diseases: 81.29%
# DeepWeeds: 42.47%
# Mango Leaf Disease: 41.55%
# Dangerous Insects: 36.58%
# Soybean Seeds: 33.49%
# Bean Leaf Lesions: 23.01%
# Durum Wheat: 14.28%
#
# Models ranked by average CV (most variable performance across datasets):
# Claude-3-haiku: 58.03%
# Gemini-pro-1.5: 39.86%
# Gemini-flash-1.5: 38.85%
# Claude-3.5-sonnet: 32.00%
# GPT-4o: 26.02%
#
# Most challenging identification dataset: Soybean Diseases (Average CV: 81.29%)
# Easiest identification dataset: Durum Wheat (Average CV: 14.28%)
#
# Most consistent model: GPT-4o (Average CV: 26.02%)
# Least consistent model: Claude-3-haiku (Average CV: 58.03%)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style parameters
plt.rcParams.update({
    'font.family': 'Arial',
    'font.size': 12,
    'axes.labelsize': 12,
    'axes.titlesize': 13,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'legend.fontsize': 11,
})

# Create the heatmap for CV
plt.figure(figsize=(5, 5))  # Adjust the size as needed for a single column
sns.heatmap(cv_table, annot=False, cmap="viridis_r", cbar_kws={'label': 'CV (%)'})
plt.title("CV (%) of F1 Scores")
plt.ylabel("Datasets")
plt.xlabel("Models")
plt.tight_layout()
plt.savefig('analysis/cv_heatmap_identification_final.pdf', dpi=300, bbox_inches='tight')

plt.close()

print("\nCompact heatmap saved as 'analysis/cv_heatmap_identification_final.pdf'")
# Out:
# Compact heatmap saved as 'analysis/cv_heatmap_identification_final.pdf'

# %% [markdown]
# # Impact of Exact Few shot examples

# %%
import pandas as pd
import numpy as np
import os
import ast
from sklearn.metrics import precision_recall_fscore_support

def calculate_f1_score(true_labels, pred_labels):
    precision, recall, f1, _ = precision_recall_fscore_support(true_labels, pred_labels, average='weighted', zero_division=0)
    return f1 * 100  # Convert to percentage

def calculate_baseline(model_folder, dataset):
    file_path = f'results/{model_folder}/{dataset}.csv'
    df = pd.read_csv(file_path, engine='python')
    
    true_labels = df['1'].fillna('Unknown')
    pred_labels_0 = df['# of Shots 0'].fillna('NA_placeholder')
    
    return calculate_f1_score(true_labels, pred_labels_0)

def analyze_example_impact(model_folder, dataset, shot):
    file_path = f'results/{model_folder}/{dataset}.csv'
    df = pd.read_csv(file_path, engine='python')
    
    true_labels = df['1'].fillna('Unknown')
    pred_labels = df[f'# of Shots {shot}'].fillna('NA_placeholder')
    
    example_cats = f'Example Categories {shot}'
    df['has_exact'] = df.apply(lambda row: 
        row['1'] in ast.literal_eval(row[example_cats]) if isinstance(row[example_cats], str) else False, 
        axis=1
    )
    
    perf_with_exact = calculate_f1_score(true_labels[df['has_exact']], pred_labels[df['has_exact']])
    perf_without_exact = calculate_f1_score(true_labels[~df['has_exact']], pred_labels[~df['has_exact']])
    
    return perf_with_exact, perf_without_exact

# Assuming dataset_mapping is defined elsewhere in your code
# dataset_mapping = {...}

results = {}
baselines = {}
for dataset, (category, metric, subcategory) in dataset_mapping.items():
    if category == 'Identification (I)':
        results[dataset] = {shot: {'with_exact': [], 'without_exact': []} for shot in [1, 2, 4, 8]}
        baselines[dataset] = []
        for model_folder in os.listdir('results'):
            if os.path.isdir(os.path.join('results', model_folder)) and model_folder != 'LLaVA v1.6 34B':
                try:
                    # Calculate baseline (0-shot) for each model
                    baseline = calculate_baseline(model_folder, dataset)
                    baselines[dataset].append(baseline)
                    
                    for shot in [1, 2, 4, 8]:
                        with_exact, without_exact = analyze_example_impact(model_folder, dataset, shot)
                        results[dataset][shot]['with_exact'].append(with_exact)
                        results[dataset][shot]['without_exact'].append(without_exact)
                except Exception as e:
                    print(f"Error processing {model_folder}/{dataset}: {str(e)}")

# Create DataFrame
data = []
for dataset in results:
    row = {'Dataset': dataset}
    avg_0shot = np.nanmean(baselines[dataset])
    row[('Baseline', '0-shot')] = f"{avg_0shot:05.2f}"
    
    total_with_exact = 0
    total_without_exact = 0
    for shot in [1, 2, 4, 8]:
        avg_with_exact = np.nanmean(results[dataset][shot]['with_exact'])
        avg_without_exact = np.nanmean(results[dataset][shot]['without_exact'])
        
        delta_with = avg_with_exact - avg_0shot
        delta_without = avg_without_exact - avg_0shot
        
        row[('Bullseye', f'{shot}-shot')] = f"{delta_with:+06.2f}"
        row[('Non-Bullseye', f'{shot}-shot')] = f"{delta_without:+06.2f}"
        
        total_with_exact += delta_with
        total_without_exact += delta_without
    
    row[('Bullseye', 'Average Impact')] = f"{total_with_exact / 4:+06.2f}"
    row[('Non-Bullseye', 'Average Impact')] = f"{total_without_exact / 4:+06.2f}"
    
    data.append(row)

df_results = pd.DataFrame(data)
df_results.set_index('Dataset', inplace=True)

# Reorder columns
column_order = [('Baseline', '0-shot')] + \
               [('Bullseye', f'{shot}-shot') for shot in [1, 2, 4, 8]] + \
               [('Bullseye', 'Average Impact')] + \
               [('Non-Bullseye', f'{shot}-shot') for shot in [1, 2, 4, 8]] + \
               [('Non-Bullseye', 'Average Impact')]
df_results = df_results.reindex(columns=pd.MultiIndex.from_tuples(column_order))

# Calculate average across datasets
avg_row = df_results.apply(lambda x: pd.to_numeric(x.str.lstrip('+'), errors='coerce').mean())
avg_row = avg_row.apply(lambda x: f"{x:+06.2f}" if pd.notnull(x) else x)
avg_row[('Baseline', '0-shot')] = f"{float(avg_row[('Baseline', '0-shot')].lstrip('+')):05.2f}"

# Create a DataFrame for the average row and concatenate it with df_results
avg_df = pd.DataFrame([avg_row], index=['Average'])
bulleye_results = pd.concat([df_results, avg_df])

print(bulleye_results)
# Out:
#                    Baseline Bullseye                                         \
#                      0-shot   1-shot  2-shot  4-shot  8-shot Average Impact
# Durum Wheat           51.18   +31.10  +23.74  +28.02  +30.67         +28.38
# Soybean Seeds         27.95   +27.10  +15.54  +13.79  +21.77         +19.55
# Mango Leaf Disease    44.76   +22.61  +22.90  +17.34  +28.30         +22.79
# Bean Leaf Lesions     67.53   +11.46  +05.01  +07.67  +06.90         +07.76
# Soybean Diseases      12.23   +49.05  +17.71  +09.26  +06.54         +20.64
# Dangerous Insects     75.83   -12.05  -10.92  -12.67  -04.15         -09.95
# DeepWeeds             30.23   +22.37  +24.79  +13.85  +12.86         +18.47
# Average               44.24   +21.66  +14.11  +11.04  +14.70         +15.38
#
#                    Non-Bullseye
#                          1-shot  2-shot  4-shot  8-shot Average Impact
# Durum Wheat              -01.74  +01.03  -04.39  -11.85         -04.24
# Soybean Seeds            -01.48  +05.57  +05.44  +09.20         +04.68
# Mango Leaf Disease       -02.02  -02.96  -00.40  +03.31         -00.52
# Bean Leaf Lesions        -06.08  -05.61  -09.65  -07.87         -07.30
# Soybean Diseases         +00.26  +06.98  +04.95  +11.73         +05.98
# Dangerous Insects        -00.92  +02.04  +03.37  +01.90         +01.60
# DeepWeeds                -02.03  -03.32  -00.35  +01.55         -01.04
# Average                  -02.00  +00.53  -00.15  +01.14         -00.12

# %%
bulleye_results.head(10)
# Out:
#                    Baseline Bullseye                                         \
#                      0-shot   1-shot  2-shot  4-shot  8-shot Average Impact
# Durum Wheat           51.18   +31.10  +23.74  +28.02  +30.67         +28.38
# Soybean Seeds         27.95   +27.10  +15.54  +13.79  +21.77         +19.55
# Mango Leaf Disease    44.76   +22.61  +22.90  +17.34  +28.30         +22.79
# Bean Leaf Lesions     67.53   +11.46  +05.01  +07.67  +06.90         +07.76
# Soybean Diseases      12.23   +49.05  +17.71  +09.26  +06.54         +20.64
# Dangerous Insects     75.83   -12.05  -10.92  -12.67  -04.15         -09.95
# DeepWeeds             30.23   +22.37  +24.79  +13.85  +12.86         +18.47
# Average               44.24   +21.66  +14.11  +11.04  +14.70         +15.38
#
#                    Non-Bullseye
#                          1-shot  2-shot  4-shot  8-shot Average Impact
# Durum Wheat              -01.74  +01.03  -04.39  -11.85         -04.24
# Soybean Seeds            -01.48  +05.57  +05.44  +09.20         +04.68
# Mango Leaf Disease       -02.02  -02.96  -00.40  +03.31         -00.52
# Bean Leaf Lesions        -06.08  -05.61  -09.65  -07.87         -07.30
# Soybean Diseases         +00.26  +06.98  +04.95  +11.73         +05.98
# Dangerous Insects        -00.92  +02.04  +03.37  +01.90         +01.60
# DeepWeeds                -02.03  -03.32  -00.35  +01.55         -01.04
# Average                  -02.00  +00.53  -00.15  +01.14         -00.12

# %% [markdown]
# # with highlights

# %%
import pandas as pd
import numpy as np

def highlight_and_format(s):
    # Convert to numeric, ignoring the '+' sign and '%'
    numeric_s = pd.to_numeric(s.str.replace('+', '').str.replace('%', ''), errors='coerce')
    
    # Identify shot columns (1, 2, 4, 8) for both Bullseye and Non-Bullseye
    shot_columns = [col for col in s.index if col[1] in ['1-shot', '2-shot', '4-shot', '8-shot']]
    
    # Find highest and lowest values in shot columns
    shot_values = numeric_s[shot_columns]
    highest = shot_values.max()
    lowest = shot_values.min()
    
    formatted = []
    for idx, value in s.items():
        if 'Average Impact' in idx[1]:
            formatted.append(f'\\textbf{{{value}}}')
        elif idx in shot_columns:
            if numeric_s[idx] == highest:
                formatted.append(f'\\cellcolor{{green!25}}{value}')
            elif numeric_s[idx] == lowest:
                formatted.append(f'\\cellcolor{{red!25}}{value}')
            else:
                formatted.append(value)
        else:
            formatted.append(value)
    
    return formatted

def to_latex_with_multicolumn(df):
    # Create a copy of the DataFrame to avoid modifying the original
    df_highlighted = df.copy()

    # Apply highlighting and formatting to each row
    for idx in df_highlighted.index:
        row = df_highlighted.loc[idx]
        formatted_row = highlight_and_format(row)
        df_highlighted.loc[idx] = formatted_row

    latex = df_highlighted.to_latex(multicolumn=True, multicolumn_format='c', multirow=True,
                        column_format='l' + 'c'*len(df_highlighted.columns), 
                        escape=False)
    
    # Remove the \toprule, \midrule, and \bottomrule commands
    latex = latex.replace('\\toprule', '\\hline')
    latex = latex.replace('\\midrule', '\\hline')
    latex = latex.replace('\\bottomrule', '\\hline')
    
    return latex

# Convert to LaTeX
latex_table = to_latex_with_multicolumn(bulleye_results)

# Add caption, label, and font details
latex_table = """\\begin{table*}[htbp]
\\centering
\\caption{Few Shot Learning: Impact of having at least 1 example with same category as ground truth (Bullseye Example). 
\\protect\\colorbox{green!25}{\\strut Highest} 
\\protect\\colorbox{red!25}{\\strut Lowest} across 1, 2, 4, and 8-shot settings for both Bullseye and Non-Bullseye. 
Average Impact values are in \\textbf{bold}.}
\\label{tab:Bullseye}

{\\fontsize{7pt}{8pt}\\selectfont
""" + latex_table + """}

\\end{table*}"""

print(latex_table)
# Out:
# \begin{table*}[htbp]
# \centering
# \caption{Few Shot Learning: Impact of having at least 1 example with same category as ground truth (Bullseye Example).
# \protect\colorbox{green!25}{\strut Highest}
# \protect\colorbox{red!25}{\strut Lowest} across 1, 2, 4, and 8-shot settings for both Bullseye and Non-Bullseye.
# Average Impact values are in \textbf{bold}.}
# \label{tab:Bullseye}
#
# {\fontsize{7pt}{8pt}\selectfont
# \begin{tabular}{lccccccccccc}
# \hline
#  & Baseline & \multicolumn{5}{c}{Bullseye} & \multicolumn{5}{c}{Non-Bullseye} \\
#  & 0-shot & 1-shot & 2-shot & 4-shot & 8-shot & Average Impact & 1-shot & 2-shot & 4-shot & 8-shot & Average Impact \\
# \hline
# Durum Wheat & 51.18 & \cellcolor{green!25}+31.10 & +23.74 & +28.02 & +30.67 & \textbf{+28.38} & -01.74 & +01.03 & -04.39 & \cellcolor{red!25}-11.85 & \textbf{-04.24} \\
# Soybean Seeds & 27.95 & \cellcolor{green!25}+27.10 & +15.54 & +13.79 & +21.77 & \textbf{+19.55} & \cellcolor{red!25}-01.48 & +05.57 & +05.44 & +09.20 & \textbf{+04.68} \\
# Mango Leaf Disease & 44.76 & +22.61 & +22.90 & +17.34 & \cellcolor{green!25}+28.30 & \textbf{+22.79} & -02.02 & \cellcolor{red!25}-02.96 & -00.40 & +03.31 & \textbf{-00.52} \\
# Bean Leaf Lesions & 67.53 & \cellcolor{green!25}+11.46 & +05.01 & +07.67 & +06.90 & \textbf{+07.76} & -06.08 & -05.61 & \cellcolor{red!25}-09.65 & -07.87 & \textbf{-07.30} \\
# Soybean Diseases & 12.23 & \cellcolor{green!25}+49.05 & +17.71 & +09.26 & +06.54 & \textbf{+20.64} & \cellcolor{red!25}+00.26 & +06.98 & +04.95 & +11.73 & \textbf{+05.98} \\
# Dangerous Insects & 75.83 & -12.05 & -10.92 & \cellcolor{red!25}-12.67 & -04.15 & \textbf{-09.95} & -00.92 & +02.04 & \cellcolor{green!25}+03.37 & +01.90 & \textbf{+01.60} \\
# DeepWeeds & 30.23 & +22.37 & \cellcolor{green!25}+24.79 & +13.85 & +12.86 & \textbf{+18.47} & -02.03 & \cellcolor{red!25}-03.32 & -00.35 & +01.55 & \textbf{-01.04} \\
# Average & 44.24 & \cellcolor{green!25}+21.66 & +14.11 & +11.04 & +14.70 & \textbf{+15.38} & \cellcolor{red!25}-02.00 & +00.53 & -00.15 & +01.14 & \textbf{-00.12} \\
# \hline
# \end{tabular}
# }
#
# \end{table*}

# %% [markdown]
# # fixing

# %% [markdown]
# ## Debugging issue with insect (just use logs for explaination)

# %%
# import pandas as pd
# import numpy as np
# import os
# import ast
# from sklearn.metrics import precision_recall_fscore_support

# def calculate_f1_score(true_labels, pred_labels):
#     precision, recall, f1, _ = precision_recall_fscore_support(true_labels, pred_labels, average='weighted', zero_division=0)
#     return f1 * 100  # Convert to percentage

# def analyze_performance(model_folder, dataset, shot):
#     file_path = f'results/{model_folder}/{dataset}.csv'
#     df = pd.read_csv(file_path, engine='python')
    
#     true_labels = df['1'].fillna('Unknown')
#     pred_labels_0 = df['# of Shots 0'].fillna('NA_placeholder')
#     pred_labels = df[f'# of Shots {shot}'].fillna('NA_placeholder')
    
#     baseline = calculate_f1_score(true_labels, pred_labels_0)
#     performance = calculate_f1_score(true_labels, pred_labels)
    
#     example_cats = f'Example Categories {shot}'
#     df['has_exact'] = df.apply(lambda row: 
#         row['1'] in ast.literal_eval(row[example_cats]) if isinstance(row[example_cats], str) else False, 
#         axis=1
#     )
    
#     perf_with_exact = calculate_f1_score(true_labels[df['has_exact']], pred_labels[df['has_exact']])
#     perf_without_exact = calculate_f1_score(true_labels[~df['has_exact']], pred_labels[~df['has_exact']])
#     bullseye_proportion = df['has_exact'].mean()
    
#     return baseline, performance, perf_with_exact, perf_without_exact, bullseye_proportion

# # Assuming dataset_mapping is defined
# dataset_mapping = {
#     'Durum Wheat': ('Identification (I)', 'F1', 'Seed Morphology'),
#     'Soybean Seeds': ('Identification (I)', 'F1', 'Seed Morphology'),
#     'Mango Leaf Disease': ('Identification (I)', 'F1', 'Foliar Stress'),
#     'Bean Leaf Lesions': ('Identification (I)', 'F1', 'Foliar Stress'),
#     'Soybean Diseases': ('Identification (I)', 'F1', 'Foliar Stress'),
#     'Dangerous Insects': ('Identification (I)', 'F1', 'Invasive Species'),
#     'DeepWeeds': ('Identification (I)', 'F1', 'Invasive Species'),
# }

# results = {}
# for dataset in dataset_mapping:
#     results[dataset] = {shot: {'baseline': [], 'performance': [], 'with_exact': [], 'without_exact': [], 'bullseye_prop': []} for shot in [0, 1, 2, 4, 8]}

# for dataset in dataset_mapping:
#     print(f"\nAnalyzing {dataset}:")
#     for model_folder in os.listdir('results'):
#         if os.path.isdir(os.path.join('results', model_folder)) and model_folder != 'LLaVA v1.6 34B':
#             print(f"  Model: {model_folder}")
#             try:
#                 for shot in [0, 1, 2, 4, 8]:
#                     baseline, performance, with_exact, without_exact, bullseye_prop = analyze_performance(model_folder, dataset, shot)
#                     results[dataset][shot]['baseline'].append(baseline)
#                     results[dataset][shot]['performance'].append(performance)
#                     results[dataset][shot]['with_exact'].append(with_exact)
#                     results[dataset][shot]['without_exact'].append(without_exact)
#                     results[dataset][shot]['bullseye_prop'].append(bullseye_prop)
                    
#                     print(f"    {shot}-shot: Baseline={baseline:.2f}, Performance={performance:.2f}, Delta={performance-baseline:.2f}")
#                     if shot > 0:
#                         print(f"      With exact={with_exact:.2f}, Without exact={without_exact:.2f}, Bullseye prop={bullseye_prop:.2%}")
#             except Exception as e:
#                 print(f"    Error processing {model_folder}/{dataset}: {str(e)}")

# print("\nAggregated Results:")
# for dataset in results:
#     print(f"\n{dataset}:")
#     avg_baseline = np.mean(results[dataset][0]['baseline'])
#     print(f"  Average Baseline (0-shot): {avg_baseline:.2f}")
#     for shot in [1, 2, 4, 8]:
#         avg_performance = np.mean(results[dataset][shot]['performance'])
#         avg_with_exact = np.mean(results[dataset][shot]['with_exact'])
#         avg_without_exact = np.mean(results[dataset][shot]['without_exact'])
#         avg_bullseye_prop = np.mean(results[dataset][shot]['bullseye_prop'])
#         print(f"  {shot}-shot:")
#         print(f"    Avg Performance: {avg_performance:.2f}, Delta: {avg_performance - avg_baseline:.2f}")
#         print(f"    Avg With Exact: {avg_with_exact:.2f}, Delta: {avg_with_exact - avg_baseline:.2f}")
#         print(f"    Avg Without Exact: {avg_without_exact:.2f}, Delta: {avg_without_exact - avg_baseline:.2f}")
#         print(f"    Avg Bullseye Proportion: {avg_bullseye_prop:.2%}")
# Out:
# Analyzing Durum Wheat:
#   Model: Gemini-pro-1.5
#     0-shot: Baseline=55.56, Performance=55.56, Delta=0.00
#     1-shot: Baseline=55.56, Performance=63.44, Delta=7.89
#       With exact=85.32, Without exact=53.91, Bullseye prop=31.31%
#     2-shot: Baseline=55.56, Performance=74.03, Delta=18.47
#       With exact=85.96, Without exact=54.82, Bullseye prop=57.58%
#     4-shot: Baseline=55.56, Performance=77.45, Delta=21.89
#       With exact=86.42, Without exact=33.94, Bullseye prop=82.83%
#     8-shot: Baseline=55.56, Performance=79.66, Delta=24.10
#       With exact=83.02, Without exact=0.00, Bullseye prop=95.96%
#   Model: GPT-4o
#     0-shot: Baseline=55.10, Performance=55.10, Delta=0.00
#     1-shot: Baseline=55.10, Performance=75.00, Delta=19.90
#       With exact=83.04, Without exact=71.80, Bullseye prop=24.24%
#     2-shot: Baseline=55.10, Performance=85.19, Delta=30.09
#       With exact=92.44, Without exact=76.56, Bullseye prop=55.56%
#     4-shot: Baseline=55.10, Performance=92.89, Delta=37.79
#       With exact=97.40, Without exact=76.48, Bullseye prop=77.78%
#     8-shot: Baseline=55.10, Performance=95.94, Delta=40.84
#       With exact=96.80, Without exact=73.33, Bullseye prop=94.95%
#   Model: Claude-3.5-sonnet
#     0-shot: Baseline=55.56, Performance=55.56, Delta=0.00
#     1-shot: Baseline=55.56, Performance=55.56, Delta=0.00
#       With exact=49.27, Without exact=60.26, Bullseye prop=41.41%
#     2-shot: Baseline=55.56, Performance=77.76, Delta=22.20
#       With exact=81.46, Without exact=66.83, Bullseye prop=62.63%
#     4-shot: Baseline=55.56, Performance=79.07, Delta=23.52
#       With exact=83.15, Without exact=60.69, Bullseye prop=75.76%
#     8-shot: Baseline=55.56, Performance=89.66, Delta=34.11
#       With exact=90.23, Without exact=73.33, Bullseye prop=94.95%
#   Model: Gemini-flash-1.5
#     0-shot: Baseline=53.64, Performance=53.64, Delta=0.00
#     1-shot: Baseline=53.64, Performance=64.64, Delta=11.00
#       With exact=100.00, Without exact=49.30, Bullseye prop=30.30%
#     2-shot: Baseline=53.64, Performance=61.04, Delta=7.41
#       With exact=71.65, Without exact=46.50, Bullseye prop=57.58%
#     4-shot: Baseline=53.64, Performance=70.65, Delta=17.01
#       With exact=84.91, Without exact=30.77, Bullseye prop=73.74%
#     8-shot: Baseline=53.64, Performance=83.70, Delta=30.07
#       With exact=84.38, Without exact=50.00, Bullseye prop=97.98%
#   Model: Claude-3-haiku
#     0-shot: Baseline=36.06, Performance=36.06, Delta=0.00
#     1-shot: Baseline=36.06, Performance=42.12, Delta=6.06
#       With exact=93.78, Without exact=11.94, Bullseye prop=32.32%
#     2-shot: Baseline=36.06, Performance=32.99, Delta=-3.07
#       With exact=43.07, Without exact=16.33, Bullseye prop=57.58%
#     4-shot: Baseline=36.06, Performance=42.27, Delta=6.21
#       With exact=44.14, Without exact=32.08, Bullseye prop=81.82%
#     8-shot: Baseline=36.06, Performance=53.29, Delta=17.23
#       With exact=54.81, Without exact=0.00, Bullseye prop=96.97%
#
# Analyzing Soybean Seeds:
#   Model: Gemini-pro-1.5
#     0-shot: Baseline=26.24, Performance=26.24, Delta=0.00
#     1-shot: Baseline=26.24, Performance=30.63, Delta=4.39
#       With exact=43.87, Without exact=26.18, Bullseye prop=21.00%
#     2-shot: Baseline=26.24, Performance=37.37, Delta=11.12
#       With exact=50.12, Without exact=29.37, Bullseye prop=35.00%
#     4-shot: Baseline=26.24, Performance=38.12, Delta=11.88
#       With exact=41.46, Without exact=33.06, Bullseye prop=57.00%
#     8-shot: Baseline=26.24, Performance=52.19, Delta=25.94
#       With exact=55.30, Without exact=38.43, Bullseye prop=82.00%
#   Model: GPT-4o
#     0-shot: Baseline=19.00, Performance=19.00, Delta=0.00
#     1-shot: Baseline=19.00, Performance=28.48, Delta=9.48
#       With exact=28.84, Without exact=27.97, Bullseye prop=21.00%
#     2-shot: Baseline=19.00, Performance=38.35, Delta=19.35
#       With exact=39.76, Without exact=38.42, Bullseye prop=30.00%
#     4-shot: Baseline=19.00, Performance=39.16, Delta=20.16
#       With exact=46.91, Without exact=24.68, Bullseye prop=62.00%
#     8-shot: Baseline=19.00, Performance=48.29, Delta=29.30
#       With exact=50.40, Without exact=36.07, Bullseye prop=76.00%
#   Model: Claude-3.5-sonnet
#     0-shot: Baseline=38.70, Performance=38.70, Delta=0.00
#     1-shot: Baseline=38.70, Performance=44.62, Delta=5.92
#       With exact=61.88, Without exact=41.17, Bullseye prop=19.00%
#     2-shot: Baseline=38.70, Performance=48.68, Delta=9.97
#       With exact=48.29, Without exact=48.90, Bullseye prop=41.00%
#     4-shot: Baseline=38.70, Performance=48.23, Delta=9.53
#       With exact=47.54, Without exact=48.85, Bullseye prop=53.00%
#     8-shot: Baseline=38.70, Performance=51.17, Delta=12.47
#       With exact=52.69, Without exact=43.77, Bullseye prop=85.00%
#   Model: Gemini-flash-1.5
#     0-shot: Baseline=24.58, Performance=24.58, Delta=0.00
#     1-shot: Baseline=24.58, Performance=30.93, Delta=6.35
#       With exact=71.31, Without exact=20.35, Bullseye prop=20.00%
#     2-shot: Baseline=24.58, Performance=30.19, Delta=5.62
#       With exact=37.03, Without exact=25.51, Bullseye prop=39.00%
#     4-shot: Baseline=24.58, Performance=34.51, Delta=9.94
#       With exact=44.26, Without exact=22.85, Bullseye prop=58.00%
#     8-shot: Baseline=24.58, Performance=48.09, Delta=23.51
#       With exact=52.76, Without exact=29.00, Bullseye prop=80.00%
#   Model: Claude-3-haiku
#     0-shot: Baseline=31.24, Performance=31.24, Delta=0.00
#     1-shot: Baseline=31.24, Performance=28.21, Delta=-3.03
#       With exact=69.36, Without exact=16.69, Bullseye prop=21.00%
#     2-shot: Baseline=31.24, Performance=30.23, Delta=-1.01
#       With exact=42.26, Without exact=25.44, Bullseye prop=28.00%
#     4-shot: Baseline=31.24, Performance=34.25, Delta=3.01
#       With exact=28.52, Without exact=37.54, Bullseye prop=50.00%
#     8-shot: Baseline=31.24, Performance=38.02, Delta=6.78
#       With exact=37.44, Without exact=38.52, Bullseye prop=86.00%
#
# Analyzing Mango Leaf Disease:
#   Model: Gemini-pro-1.5
#     0-shot: Baseline=42.91, Performance=42.91, Delta=0.00
#     1-shot: Baseline=42.91, Performance=41.24, Delta=-1.67
#       With exact=60.00, Without exact=39.61, Bullseye prop=5.21%
#     2-shot: Baseline=42.91, Performance=52.81, Delta=9.90
#       With exact=79.70, Without exact=43.84, Bullseye prop=19.79%
#     4-shot: Baseline=42.91, Performance=47.11, Delta=4.20
#       With exact=62.72, Without exact=38.35, Bullseye prop=33.33%
#     8-shot: Baseline=42.91, Performance=71.68, Delta=28.77
#       With exact=87.42, Without exact=54.56, Bullseye prop=51.04%
#   Model: GPT-4o
#     0-shot: Baseline=58.41, Performance=58.41, Delta=0.00
#     1-shot: Baseline=58.41, Performance=63.40, Delta=4.99
#       With exact=73.85, Without exact=61.78, Bullseye prop=13.54%
#     2-shot: Baseline=58.41, Performance=63.11, Delta=4.70
#       With exact=70.00, Without exact=60.41, Bullseye prop=20.83%
#     4-shot: Baseline=58.41, Performance=63.33, Delta=4.92
#       With exact=70.66, Without exact=59.11, Bullseye prop=33.33%
#     8-shot: Baseline=58.41, Performance=80.96, Delta=22.55
#       With exact=92.05, Without exact=58.15, Bullseye prop=65.62%
#   Model: Claude-3.5-sonnet
#     0-shot: Baseline=49.82, Performance=49.82, Delta=0.00
#     1-shot: Baseline=49.82, Performance=52.80, Delta=2.98
#       With exact=75.24, Without exact=49.55, Bullseye prop=14.58%
#     2-shot: Baseline=49.82, Performance=49.23, Delta=-0.59
#       With exact=44.54, Without exact=51.74, Bullseye prop=29.17%
#     4-shot: Baseline=49.82, Performance=54.72, Delta=4.90
#       With exact=54.84, Without exact=55.97, Bullseye prop=40.62%
#     8-shot: Baseline=49.82, Performance=61.68, Delta=11.86
#       With exact=58.06, Without exact=67.54, Bullseye prop=63.54%
#   Model: Gemini-flash-1.5
#     0-shot: Baseline=42.85, Performance=42.85, Delta=0.00
#     1-shot: Baseline=42.85, Performance=44.80, Delta=1.95
#       With exact=61.11, Without exact=41.98, Bullseye prop=12.50%
#     2-shot: Baseline=42.85, Performance=47.14, Delta=4.28
#       With exact=79.06, Without exact=36.80, Bullseye prop=22.92%
#     4-shot: Baseline=42.85, Performance=49.21, Delta=6.36
#       With exact=73.87, Without exact=37.74, Bullseye prop=31.25%
#     8-shot: Baseline=42.85, Performance=64.66, Delta=21.81
#       With exact=80.71, Without exact=34.87, Bullseye prop=59.38%
#   Model: Claude-3-haiku
#     0-shot: Baseline=29.83, Performance=29.83, Delta=0.00
#     1-shot: Baseline=29.83, Performance=26.90, Delta=-2.94
#       With exact=66.67, Without exact=20.81, Bullseye prop=13.54%
#     2-shot: Baseline=29.83, Performance=28.17, Delta=-1.66
#       With exact=65.00, Without exact=16.22, Bullseye prop=25.00%
#     4-shot: Baseline=29.83, Performance=39.24, Delta=9.40
#       With exact=48.44, Without exact=30.65, Bullseye prop=44.79%
#     8-shot: Baseline=29.83, Performance=38.92, Delta=9.09
#       With exact=47.11, Without exact=25.26, Bullseye prop=58.33%
#
# Analyzing Bean Leaf Lesions:
#   Model: Gemini-pro-1.5
#     0-shot: Baseline=77.22, Performance=77.22, Delta=0.00
#     1-shot: Baseline=77.22, Performance=75.30, Delta=-1.92
#       With exact=89.78, Without exact=69.13, Bullseye prop=29.29%
#     2-shot: Baseline=77.22, Performance=74.66, Delta=-2.56
#       With exact=79.31, Without exact=69.61, Bullseye prop=49.49%
#     4-shot: Baseline=77.22, Performance=74.15, Delta=-3.06
#       With exact=80.25, Without exact=56.55, Bullseye prop=73.74%
#     8-shot: Baseline=77.22, Performance=78.17, Delta=0.95
#       With exact=77.76, Without exact=100.00, Bullseye prop=97.98%
#   Model: GPT-4o
#     0-shot: Baseline=65.92, Performance=65.92, Delta=0.00
#     1-shot: Baseline=65.92, Performance=78.77, Delta=12.85
#       With exact=73.39, Without exact=80.72, Bullseye prop=27.27%
#     2-shot: Baseline=65.92, Performance=72.72, Delta=6.80
#       With exact=74.38, Without exact=71.49, Bullseye prop=56.57%
#     4-shot: Baseline=65.92, Performance=85.80, Delta=19.88
#       With exact=84.96, Without exact=91.80, Bullseye prop=87.88%
#     8-shot: Baseline=65.92, Performance=86.90, Delta=20.99
#       With exact=87.67, Without exact=50.00, Bullseye prop=97.98%
#   Model: Claude-3.5-sonnet
#     0-shot: Baseline=68.65, Performance=68.65, Delta=0.00
#     1-shot: Baseline=68.65, Performance=67.18, Delta=-1.47
#       With exact=58.35, Without exact=70.46, Bullseye prop=32.32%
#     2-shot: Baseline=68.65, Performance=73.55, Delta=4.90
#       With exact=65.17, Without exact=82.48, Bullseye prop=53.54%
#     4-shot: Baseline=68.65, Performance=78.50, Delta=9.85
#       With exact=78.04, Without exact=79.37, Bullseye prop=83.84%
#     8-shot: Baseline=68.65, Performance=84.78, Delta=16.13
#       With exact=85.25, Without exact=85.00, Bullseye prop=95.96%
#   Model: Gemini-flash-1.5
#     0-shot: Baseline=70.61, Performance=70.61, Delta=0.00
#     1-shot: Baseline=70.61, Performance=68.26, Delta=-2.35
#       With exact=97.22, Without exact=51.68, Bullseye prop=36.36%
#     2-shot: Baseline=70.61, Performance=62.79, Delta=-7.82
#       With exact=82.68, Without exact=32.00, Bullseye prop=63.64%
#     4-shot: Baseline=70.61, Performance=75.76, Delta=5.14
#       With exact=82.34, Without exact=36.36, Bullseye prop=85.86%
#     8-shot: Baseline=70.61, Performance=73.42, Delta=2.80
#       With exact=74.78, Without exact=33.33, Bullseye prop=96.97%
#   Model: Claude-3-haiku
#     0-shot: Baseline=55.26, Performance=55.26, Delta=0.00
#     1-shot: Baseline=55.26, Performance=48.11, Delta=-7.15
#       With exact=76.21, Without exact=35.27, Bullseye prop=33.33%
#     2-shot: Baseline=55.26, Performance=58.08, Delta=2.82
#       With exact=61.17, Without exact=54.06, Bullseye prop=53.54%
#     4-shot: Baseline=55.26, Performance=45.50, Delta=-9.76
#       With exact=50.40, Without exact=25.31, Bullseye prop=82.83%
#     8-shot: Baseline=55.26, Performance=46.42, Delta=-8.84
#       With exact=46.68, Without exact=30.00, Bullseye prop=94.95%
#
# Analyzing Soybean Diseases:
#   Model: Gemini-pro-1.5
#     0-shot: Baseline=21.78, Performance=21.78, Delta=0.00
#     1-shot: Baseline=21.78, Performance=22.93, Delta=1.15
#       With exact=33.33, Without exact=22.88, Bullseye prop=9.09%
#     2-shot: Baseline=21.78, Performance=23.23, Delta=1.45
#       With exact=26.95, Without exact=21.62, Bullseye prop=25.25%
#     4-shot: Baseline=21.78, Performance=26.13, Delta=4.35
#       With exact=23.40, Without exact=28.22, Bullseye prop=35.35%
#     8-shot: Baseline=21.78, Performance=24.41, Delta=2.63
#       With exact=26.27, Without exact=21.03, Bullseye prop=63.64%
#   Model: GPT-4o
#     0-shot: Baseline=3.70, Performance=3.70, Delta=0.00
#     1-shot: Baseline=3.70, Performance=20.37, Delta=16.67
#       With exact=nan, Without exact=20.37, Bullseye prop=0.00%
#     2-shot: Baseline=3.70, Performance=59.26, Delta=55.56
#       With exact=nan, Without exact=59.26, Bullseye prop=0.00%
#     4-shot: Baseline=3.70, Performance=24.07, Delta=20.37
#       With exact=nan, Without exact=24.07, Bullseye prop=0.00%
#     8-shot: Baseline=3.70, Performance=62.96, Delta=59.26
#       With exact=nan, Without exact=62.96, Bullseye prop=0.00%
#   Model: Claude-3.5-sonnet
#     0-shot: Baseline=8.54, Performance=8.54, Delta=0.00
#     1-shot: Baseline=8.54, Performance=9.57, Delta=1.03
#       With exact=50.12, Without exact=5.54, Bullseye prop=11.11%
#     2-shot: Baseline=8.54, Performance=8.23, Delta=-0.31
#       With exact=14.68, Without exact=6.54, Bullseye prop=21.21%
#     4-shot: Baseline=8.54, Performance=14.51, Delta=5.97
#       With exact=17.99, Without exact=14.15, Bullseye prop=27.27%
#     8-shot: Baseline=8.54, Performance=11.07, Delta=2.53
#       With exact=11.08, Without exact=12.14, Bullseye prop=56.57%
#   Model: Gemini-flash-1.5
#     0-shot: Baseline=14.41, Performance=14.41, Delta=0.00
#     1-shot: Baseline=14.41, Performance=19.30, Delta=4.89
#       With exact=61.67, Without exact=13.62, Bullseye prop=10.10%
#     2-shot: Baseline=14.41, Performance=13.58, Delta=-0.83
#       With exact=39.23, Without exact=8.61, Bullseye prop=18.18%
#     4-shot: Baseline=14.41, Performance=15.96, Delta=1.55
#       With exact=20.95, Without exact=14.19, Bullseye prop=44.44%
#     8-shot: Baseline=14.41, Performance=23.67, Delta=9.26
#       With exact=23.45, Without exact=23.63, Bullseye prop=60.61%
#   Model: Claude-3-haiku
#     0-shot: Baseline=12.69, Performance=12.69, Delta=0.00
#     1-shot: Baseline=12.69, Performance=7.96, Delta=-4.74
#       With exact=100.00, Without exact=0.00, Bullseye prop=8.08%
#     2-shot: Baseline=12.69, Performance=4.56, Delta=-8.13
#       With exact=38.89, Without exact=0.00, Bullseye prop=12.12%
#     4-shot: Baseline=12.69, Performance=11.48, Delta=-1.22
#       With exact=23.61, Without exact=5.23, Bullseye prop=32.32%
#     8-shot: Baseline=12.69, Performance=8.81, Delta=-3.88
#       With exact=14.27, Without exact=0.00, Bullseye prop=55.56%
#
# Analyzing Dangerous Insects:
#   Model: Gemini-pro-1.5
#     0-shot: Baseline=82.67, Performance=82.67, Delta=0.00
#     1-shot: Baseline=82.67, Performance=80.33, Delta=-2.33
#       With exact=80.00, Without exact=80.81, Bullseye prop=5.56%
#     2-shot: Baseline=82.67, Performance=83.69, Delta=1.03
#       With exact=60.00, Without exact=85.42, Bullseye prop=7.78%
#     4-shot: Baseline=82.67, Performance=86.53, Delta=3.87
#       With exact=93.33, Without exact=85.29, Bullseye prop=16.67%
#     8-shot: Baseline=82.67, Performance=82.98, Delta=0.31
#       With exact=83.25, Without exact=83.23, Bullseye prop=40.00%
#   Model: GPT-4o
#     0-shot: Baseline=82.79, Performance=82.79, Delta=0.00
#     1-shot: Baseline=82.79, Performance=83.59, Delta=0.80
#       With exact=66.67, Without exact=83.99, Bullseye prop=3.33%
#     2-shot: Baseline=82.79, Performance=82.18, Delta=-0.61
#       With exact=62.50, Without exact=84.40, Bullseye prop=8.89%
#     4-shot: Baseline=82.79, Performance=85.52, Delta=2.74
#       With exact=71.43, Without exact=87.53, Bullseye prop=15.56%
#     8-shot: Baseline=82.79, Performance=82.56, Delta=-0.22
#       With exact=75.42, Without exact=90.24, Bullseye prop=51.11%
#   Model: Claude-3.5-sonnet
#     0-shot: Baseline=82.02, Performance=82.02, Delta=0.00
#     1-shot: Baseline=82.02, Performance=78.19, Delta=-3.83
#       With exact=88.89, Without exact=77.64, Bullseye prop=6.67%
#     2-shot: Baseline=82.02, Performance=84.20, Delta=2.18
#       With exact=77.78, Without exact=84.88, Bullseye prop=13.33%
#     4-shot: Baseline=82.02, Performance=82.59, Delta=0.57
#       With exact=26.19, Without exact=91.91, Bullseye prop=15.56%
#     8-shot: Baseline=82.02, Performance=81.89, Delta=-0.13
#       With exact=72.76, Without exact=89.20, Bullseye prop=38.89%
#   Model: Gemini-flash-1.5
#     0-shot: Baseline=80.38, Performance=80.38, Delta=0.00
#     1-shot: Baseline=80.38, Performance=81.01, Delta=0.63
#       With exact=83.33, Without exact=80.58, Bullseye prop=6.67%
#     2-shot: Baseline=80.38, Performance=78.62, Delta=-1.76
#       With exact=85.71, Without exact=77.66, Bullseye prop=7.78%
#     4-shot: Baseline=80.38, Performance=77.74, Delta=-2.64
#       With exact=78.83, Without exact=77.21, Bullseye prop=22.22%
#     8-shot: Baseline=80.38, Performance=82.72, Delta=2.34
#       With exact=71.61, Without exact=91.49, Bullseye prop=42.22%
#   Model: Claude-3-haiku
#     0-shot: Baseline=51.28, Performance=51.28, Delta=0.00
#     1-shot: Baseline=51.28, Performance=50.78, Delta=-0.50
#       With exact=0.00, Without exact=51.54, Bullseye prop=1.11%
#     2-shot: Baseline=51.28, Performance=54.51, Delta=3.23
#       With exact=38.54, Without exact=56.98, Bullseye prop=17.78%
#     4-shot: Baseline=51.28, Performance=52.15, Delta=0.87
#       With exact=46.00, Without exact=54.04, Bullseye prop=22.22%
#     8-shot: Baseline=51.28, Performance=45.08, Delta=-6.20
#       With exact=55.33, Without exact=34.48, Bullseye prop=45.56%
#
# Analyzing DeepWeeds:
#   Model: Gemini-pro-1.5
#     0-shot: Baseline=46.83, Performance=46.83, Delta=0.00
#     1-shot: Baseline=46.83, Performance=38.54, Delta=-8.28
#       With exact=51.85, Without exact=35.94, Bullseye prop=9.09%
#     2-shot: Baseline=46.83, Performance=47.23, Delta=0.40
#       With exact=63.53, Without exact=41.10, Bullseye prop=23.23%
#     4-shot: Baseline=46.83, Performance=46.76, Delta=-0.07
#       With exact=56.12, Without exact=40.56, Bullseye prop=35.35%
#     8-shot: Baseline=46.83, Performance=49.96, Delta=3.14
#       With exact=57.94, Without exact=41.05, Bullseye prop=53.54%
#   Model: GPT-4o
#     0-shot: Baseline=38.77, Performance=38.77, Delta=0.00
#     1-shot: Baseline=38.77, Performance=46.98, Delta=8.21
#       With exact=43.75, Without exact=47.95, Bullseye prop=16.16%
#     2-shot: Baseline=38.77, Performance=39.87, Delta=1.10
#       With exact=41.96, Without exact=40.32, Bullseye prop=17.17%
#     4-shot: Baseline=38.77, Performance=47.93, Delta=9.16
#       With exact=54.18, Without exact=43.44, Bullseye prop=40.40%
#     8-shot: Baseline=38.77, Performance=56.03, Delta=17.26
#       With exact=64.10, Without exact=47.30, Bullseye prop=54.55%
#   Model: Claude-3.5-sonnet
#     0-shot: Baseline=18.85, Performance=18.85, Delta=0.00
#     1-shot: Baseline=18.85, Performance=20.55, Delta=1.70
#       With exact=37.50, Without exact=18.67, Bullseye prop=8.08%
#     2-shot: Baseline=18.85, Performance=23.59, Delta=4.74
#       With exact=43.59, Without exact=17.90, Bullseye prop=23.23%
#     4-shot: Baseline=18.85, Performance=22.61, Delta=3.75
#       With exact=27.14, Without exact=19.59, Bullseye prop=37.37%
#     8-shot: Baseline=18.85, Performance=27.17, Delta=8.32
#       With exact=24.82, Without exact=30.76, Bullseye prop=62.63%
#   Model: Gemini-flash-1.5
#     0-shot: Baseline=32.83, Performance=32.83, Delta=0.00
#     1-shot: Baseline=32.83, Performance=29.85, Delta=-2.98
#       With exact=75.00, Without exact=28.72, Bullseye prop=4.04%
#     2-shot: Baseline=32.83, Performance=33.76, Delta=0.93
#       With exact=73.08, Without exact=26.22, Bullseye prop=13.13%
#     4-shot: Baseline=32.83, Performance=42.53, Delta=9.70
#       With exact=55.89, Without exact=36.37, Bullseye prop=30.30%
#     8-shot: Baseline=32.83, Performance=41.89, Delta=9.06
#       With exact=49.37, Without exact=32.79, Bullseye prop=52.53%
#   Model: Claude-3-haiku
#     0-shot: Baseline=13.86, Performance=13.86, Delta=0.00
#     1-shot: Baseline=13.86, Performance=15.49, Delta=1.63
#       With exact=54.87, Without exact=9.73, Bullseye prop=13.13%
#     2-shot: Baseline=13.86, Performance=14.15, Delta=0.29
#       With exact=52.94, Without exact=8.99, Bullseye prop=12.12%
#     4-shot: Baseline=13.86, Performance=16.47, Delta=2.60
#       With exact=27.05, Without exact=9.41, Bullseye prop=36.36%
#     8-shot: Baseline=13.86, Performance=15.34, Delta=1.48
#       With exact=19.23, Without exact=6.98, Bullseye prop=56.57%
#
# Aggregated Results:
#
# Durum Wheat:
#   Average Baseline (0-shot): 51.18
#   1-shot:
#     Avg Performance: 60.15, Delta: 8.97
#     Avg With Exact: 82.28, Delta: 31.10
#     Avg Without Exact: 49.44, Delta: -1.74
#     Avg Bullseye Proportion: 31.92%
#   2-shot:
#     Avg Performance: 66.20, Delta: 15.02
#     Avg With Exact: 74.92, Delta: 23.74
#     Avg Without Exact: 52.21, Delta: 1.03
#     Avg Bullseye Proportion: 58.18%
#   4-shot:
#     Avg Performance: 72.46, Delta: 21.28
#     Avg With Exact: 79.21, Delta: 28.02
#     Avg Without Exact: 46.79, Delta: -4.39
#     Avg Bullseye Proportion: 78.38%
#   8-shot:
#     Avg Performance: 80.45, Delta: 29.27
#     Avg With Exact: 81.85, Delta: 30.67
#     Avg Without Exact: 39.33, Delta: -11.85
#     Avg Bullseye Proportion: 96.16%
#
# Soybean Seeds:
#   Average Baseline (0-shot): 27.95
#   1-shot:
#     Avg Performance: 32.57, Delta: 4.62
#     Avg With Exact: 55.05, Delta: 27.10
#     Avg Without Exact: 26.47, Delta: -1.48
#     Avg Bullseye Proportion: 20.40%
#   2-shot:
#     Avg Performance: 36.96, Delta: 9.01
#     Avg With Exact: 43.49, Delta: 15.54
#     Avg Without Exact: 33.53, Delta: 5.57
#     Avg Bullseye Proportion: 34.60%
#   4-shot:
#     Avg Performance: 38.85, Delta: 10.90
#     Avg With Exact: 41.74, Delta: 13.79
#     Avg Without Exact: 33.40, Delta: 5.44
#     Avg Bullseye Proportion: 56.00%
#   8-shot:
#     Avg Performance: 47.55, Delta: 19.60
#     Avg With Exact: 49.72, Delta: 21.77
#     Avg Without Exact: 37.16, Delta: 9.20
#     Avg Bullseye Proportion: 81.80%
#
# Mango Leaf Disease:
#   Average Baseline (0-shot): 44.76
#   1-shot:
#     Avg Performance: 45.83, Delta: 1.06
#     Avg With Exact: 67.37, Delta: 22.61
#     Avg Without Exact: 42.75, Delta: -2.02
#     Avg Bullseye Proportion: 11.88%
#   2-shot:
#     Avg Performance: 48.09, Delta: 3.33
#     Avg With Exact: 67.66, Delta: 22.90
#     Avg Without Exact: 41.80, Delta: -2.96
#     Avg Bullseye Proportion: 23.54%
#   4-shot:
#     Avg Performance: 50.72, Delta: 5.96
#     Avg With Exact: 62.11, Delta: 17.34
#     Avg Without Exact: 44.36, Delta: -0.40
#     Avg Bullseye Proportion: 36.67%
#   8-shot:
#     Avg Performance: 63.58, Delta: 18.82
#     Avg With Exact: 73.07, Delta: 28.30
#     Avg Without Exact: 48.08, Delta: 3.31
#     Avg Bullseye Proportion: 59.58%
#
# Bean Leaf Lesions:
#   Average Baseline (0-shot): 67.53
#   1-shot:
#     Avg Performance: 67.52, Delta: -0.01
#     Avg With Exact: 78.99, Delta: 11.46
#     Avg Without Exact: 61.45, Delta: -6.08
#     Avg Bullseye Proportion: 31.72%
#   2-shot:
#     Avg Performance: 68.36, Delta: 0.83
#     Avg With Exact: 72.54, Delta: 5.01
#     Avg Without Exact: 61.93, Delta: -5.61
#     Avg Bullseye Proportion: 55.35%
#   4-shot:
#     Avg Performance: 71.94, Delta: 4.41
#     Avg With Exact: 75.20, Delta: 7.67
#     Avg Without Exact: 57.88, Delta: -9.65
#     Avg Bullseye Proportion: 82.83%
#   8-shot:
#     Avg Performance: 73.94, Delta: 6.41
#     Avg With Exact: 74.43, Delta: 6.90
#     Avg Without Exact: 59.67, Delta: -7.87
#     Avg Bullseye Proportion: 96.77%
#
# Soybean Diseases:
#   Average Baseline (0-shot): 12.23
#   1-shot:
#     Avg Performance: 16.03, Delta: 3.80
#     Avg With Exact: nan, Delta: nan
#     Avg Without Exact: 12.48, Delta: 0.26
#     Avg Bullseye Proportion: 7.68%
#   2-shot:
#     Avg Performance: 21.77, Delta: 9.55
#     Avg With Exact: nan, Delta: nan
#     Avg Without Exact: 19.21, Delta: 6.98
#     Avg Bullseye Proportion: 15.35%
#   4-shot:
#     Avg Performance: 18.43, Delta: 6.21
#     Avg With Exact: nan, Delta: nan
#     Avg Without Exact: 17.17, Delta: 4.95
#     Avg Bullseye Proportion: 27.88%
#   8-shot:
#     Avg Performance: 26.19, Delta: 13.96
#     Avg With Exact: nan, Delta: nan
#     Avg Without Exact: 23.95, Delta: 11.73
#     Avg Bullseye Proportion: 47.27%
#
# Dangerous Insects:
#   Average Baseline (0-shot): 75.83
#   1-shot:
#     Avg Performance: 74.78, Delta: -1.05
#     Avg With Exact: 63.78, Delta: -12.05
#     Avg Without Exact: 74.91, Delta: -0.92
#     Avg Bullseye Proportion: 4.67%
#   2-shot:
#     Avg Performance: 76.64, Delta: 0.81
#     Avg With Exact: 64.91, Delta: -10.92
#     Avg Without Exact: 77.87, Delta: 2.04
#     Avg Bullseye Proportion: 11.11%
#   4-shot:
#     Avg Performance: 76.91, Delta: 1.08
#     Avg With Exact: 63.16, Delta: -12.67
#     Avg Without Exact: 79.20, Delta: 3.37
#     Avg Bullseye Proportion: 18.44%
#   8-shot:
#     Avg Performance: 75.05, Delta: -0.78
#     Avg With Exact: 71.68, Delta: -4.15
#     Avg Without Exact: 77.73, Delta: 1.90
#     Avg Bullseye Proportion: 43.56%
#
# DeepWeeds:
#   Average Baseline (0-shot): 30.23
#   1-shot:
#     Avg Performance: 30.28, Delta: 0.05
#     Avg With Exact: 52.59, Delta: 22.37
#     Avg Without Exact: 28.20, Delta: -2.03
#     Avg Bullseye Proportion: 10.10%
#   2-shot:
#     Avg Performance: 31.72, Delta: 1.49
#     Avg With Exact: 55.02, Delta: 24.79
#     Avg Without Exact: 26.91, Delta: -3.32
#     Avg Bullseye Proportion: 17.78%
#   4-shot:
#     Avg Performance: 35.26, Delta: 5.03
#     Avg With Exact: 44.08, Delta: 13.85
#     Avg Without Exact: 29.87, Delta: -0.35
#     Avg Bullseye Proportion: 35.96%
#   8-shot:
#     Avg Performance: 38.08, Delta: 7.85
#     Avg With Exact: 43.09, Delta: 12.86
#     Avg Without Exact: 31.78, Delta: 1.55
#     Avg Bullseye Proportion: 55.96%
